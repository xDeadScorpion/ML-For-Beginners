# %% [markdown]
# # Time series forecasting with ARIMA
#
# In this notebook, we demonstrate how to:
# - prepare time series data for training an ARIMA time series forecasting model
# - implement a simple ARIMA model to forecast the next HORIZON steps ahead (time *t+1* through *t+HORIZON*) in the time series
# - evaluate the model
#
#
# The data in this example is taken from the GEFCom2014 forecasting competition<sup>1</sup>. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014. The task is to forecast future values of electricity load. In this example, we show how to forecast one time step ahead, using historical load data only.
#
# <sup>1</sup>Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from common.utils import load_data, mape
from IPython.display import Image

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
energy = load_data('./data')[['load']]
energy.head(10)
# Out:
#                         load
# 2012-01-01 00:00:00 2,698.00
# 2012-01-01 01:00:00 2,558.00
# 2012-01-01 02:00:00 2,444.00
# 2012-01-01 03:00:00 2,402.00
# 2012-01-01 04:00:00 2,403.00
# 2012-01-01 05:00:00 2,453.00
# 2012-01-01 06:00:00 2,560.00
# 2012-01-01 07:00:00 2,719.00
# 2012-01-01 08:00:00 2,916.00
# 2012-01-01 09:00:00 3,105.00

# %% [markdown]
# ## Preprocessing

# %%
train_start_dt = '2014-11-01 00:00:00'
test_start_dt = '2014-12-30 00:00:00'

# %%
energy[(energy.index < test_start_dt) & (energy.index >= train_start_dt)][['load']].rename(columns={'load':'train'}) \
    .join(energy[test_start_dt:][['load']].rename(columns={'load':'test'}), how='outer') \
    .plot(y=['train', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
train = energy.copy()[(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']]
test = energy.copy()[energy.index >= test_start_dt][['load']]

print('Training data shape: ', train.shape)
print('Test data shape: ', test.shape)
# Out:
# Training data shape:  (1416, 1)
# Test data shape:  (48, 1)

# %%
scaler = MinMaxScaler()
train['load'] = scaler.fit_transform(train)
train.head(10)
# Out:
#                      load
# 2014-11-01 00:00:00  0.10
# 2014-11-01 01:00:00  0.07
# 2014-11-01 02:00:00  0.05
# 2014-11-01 03:00:00  0.04
# 2014-11-01 04:00:00  0.06
# 2014-11-01 05:00:00  0.10
# 2014-11-01 06:00:00  0.19
# 2014-11-01 07:00:00  0.31
# 2014-11-01 08:00:00  0.40
# 2014-11-01 09:00:00  0.48

# %%
energy[(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']].rename(columns={'load':'original load'}).plot.hist(bins=100, fontsize=12)
train.rename(columns={'load':'scaled load'}).plot.hist(bins=100, fontsize=12)
plt.show()

# %%
test['load'] = scaler.transform(test)
test.head()
# Out:
#                      load
# 2014-12-30 00:00:00  0.33
# 2014-12-30 01:00:00  0.29
# 2014-12-30 02:00:00  0.27
# 2014-12-30 03:00:00  0.27
# 2014-12-30 04:00:00  0.30

# %% [markdown]
# ## Implement ARIMA

# %%
# Specify the number of steps to forecast ahead
HORIZON = 3
print('Forecasting horizon:', HORIZON, 'hours')
# Out:
# Forecasting horizon: 3 hours

# %%
order = (4, 1, 0)
seasonal_order = (1, 1, 0, 24)

model = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order)
results = model.fit()

print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               load   No. Observations:                 1416
# Model:             SARIMAX(4, 1, 0)x(1, 1, 0, 24)   Log Likelihood                3477.241
# Date:                            Thu, 12 Aug 2021   AIC                          -6942.481
# Time:                                    14:46:54   BIC                          -6911.055
# Sample:                                11-01-2014   HQIC                         -6930.729
#                                      - 12-29-2014
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8403      0.016     52.144      0.000       0.809       0.872
# ar.L2         -0.5220      0.034    -15.371      0.000      -0.589      -0.455
# ar.L3          0.1527      0.044      3.450      0.001       0.066       0.239
# ar.L4         -0.0777      0.036     -2.156      0.031      -0.148      -0.007
# ar.S.L24      -0.2338      0.024     -9.774      0.000      -0.281      -0.187
# sigma2         0.0004   8.32e-06     47.344      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):              1462.64
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.14
# Prob(H) (two-sided):                  0.07   Kurtosis:                         8.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## Evaluate

# %%
test_shifted = test.copy()

for t in range(1, HORIZON):
    test_shifted['load+'+str(t)] = test_shifted['load'].shift(-t, freq='H')

test_shifted = test_shifted.dropna(how='any')
test_shifted.head(5)
# Out:
#                      load  load+1  load+2
# 2014-12-30 00:00:00  0.33    0.29    0.27
# 2014-12-30 01:00:00  0.29    0.27    0.27
# 2014-12-30 02:00:00  0.27    0.27    0.30
# 2014-12-30 03:00:00  0.27    0.30    0.41
# 2014-12-30 04:00:00  0.30    0.41    0.57

# %%
# %%time
training_window = 720 # dedicate 30 days (720 hours) for training

train_ts = train['load']
test_ts = test_shifted

history = [x for x in train_ts]
history = history[(-training_window):]

predictions = list()

order = (2, 1, 0)
seasonal_order = (1, 1, 0, 24)

for t in range(test_ts.shape[0]):
    model = SARIMAX(endog=history, order=order, seasonal_order=seasonal_order)
    model_fit = model.fit()
    yhat = model_fit.forecast(steps = HORIZON)
    predictions.append(yhat)
    obs = list(test_ts.iloc[t])
    # move the training window
    history.append(obs[0])
    history.pop(0)
    print(test_ts.index[t])
    print(t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# 2014-12-30 00:00:00
# 1 : predicted = [0.32 0.29 0.28] expected = [0.32945389435989236, 0.2900626678603402, 0.2739480752014323]
# 2014-12-30 01:00:00
# 2 : predicted = [0.3  0.29 0.3 ] expected = [0.2900626678603402, 0.2739480752014323, 0.26812891674127126]
# 2014-12-30 02:00:00
# 3 : predicted = [0.27 0.28 0.32] expected = [0.2739480752014323, 0.26812891674127126, 0.3025962399283795]
# 2014-12-30 03:00:00
# 4 : predicted = [0.28 0.32 0.42] expected = [0.26812891674127126, 0.3025962399283795, 0.40823634735899716]
# 2014-12-30 04:00:00
# 5 : predicted = [0.3  0.39 0.54] expected = [0.3025962399283795, 0.40823634735899716, 0.5689346463742166]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.45318D+00    |proj g|=  2.50788D+00
#
# At iterate    5    f= -2.45390D+00    |proj g|=  3.89449D-01
#
# At iterate   10    f= -2.45536D+00    |proj g|=  1.63682D+00
#
# At iterate   15    f= -2.45566D+00    |proj g|=  4.10558D-03
#
# At iterate   20    f= -2.45568D+00    |proj g|=  5.16256D-02
#
# At iterate   25    f= -2.45568D+00    |proj g|=  1.75691D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     26     49      1     0     0   1.707D-02  -2.456D+00
#   F =  -2.4556783812960994
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.41942D+00    |proj g|=  1.50341D+00
#
# At iterate    5    f= -2.41973D+00    |proj g|=  5.41394D-01
#
# At iterate   10    f= -2.42221D+00    |proj g|=  1.24200D+00
#
# At iterate   15    f= -2.42274D+00    |proj g|=  9.98476D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     45      2     0     0   9.985D-03  -2.423D+00
#   F =  -2.4227431148508987
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.41939D+00    |proj g|=  1.51571D+00
#
# At iterate    5    f= -2.42074D+00    |proj g|=  1.87197D+00
#
# At iterate   10    f= -2.42244D+00    |proj g|=  7.25387D-02
#
# At iterate   15    f= -2.42264D+00    |proj g|=  6.68498D-01
#   ys=-5.144E-09  -gs= 1.083E-08 BFGS update SKIPPED
#
# At iterate   20    f= -2.42269D+00    |proj g|=  2.87046D-02
#
# At iterate   25    f= -2.42276D+00    |proj g|=  1.36133D-02
#
# At iterate   30    f= -2.42280D+00    |proj g|=  6.86766D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     35    128      3     1     0   9.157D-03  -2.423D+00
#   F =  -2.4228045249045556
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.42057D+00    |proj g|=  1.40865D+00
#
# At iterate    5    f= -2.42084D+00    |proj g|=  4.40378D-01
#
# At iterate   10    f= -2.42364D+00    |proj g|=  4.38863D-01
#
# At iterate   15    f= -2.42366D+00    |proj g|=  2.58327D-01
#
# At iterate   20    f= -2.42369D+00    |proj g|=  3.96217D-02
#
# At iterate   25    f= -2.42372D+00    |proj g|=  1.12695D-02
#
# At iterate   30    f= -2.42378D+00    |proj g|=  1.13509D-02
#
# At iterate   35    f= -2.42387D+00    |proj g|=  1.03518D-02
#   ys=-1.329E-08  -gs= 1.298E-07 BFGS update SKIPPED
#
# At iterate   40    f= -2.42388D+00    |proj g|=  1.09908D-02
#
# At iterate   45    f= -2.42388D+00    |proj g|=  5.87330D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     49    139      1     1     0   2.892D-02  -2.424D+00
#   F =  -2.4238807281056345
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.42198D+00    |proj g|=  8.36871D-01
#
# At iterate    5    f= -2.42212D+00    |proj g|=  1.12460D+00
#
# At iterate   10    f= -2.42530D+00    |proj g|=  7.57492D-01
#
# At iterate   15    f= -2.42549D+00    |proj g|=  1.66545D-02
#   ys=-7.490E-12  -gs= 1.285E-10 BFGS update SKIPPED
#
# At iterate   20    f= -2.42550D+00    |proj g|=  3.73305D-02
#
# At iterate   25    f= -2.42556D+00    |proj g|=  1.10369D-02
#
# At iterate   30    f= -2.42556D+00    |proj g|=  1.03010D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     34    128      3     1     0   1.166D-02  -2.426D+00
#   F =  -2.4255615164635422
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.42388D+00    |proj g|=  1.06644D+00
#
# At iterate    5    f= -2.42409D+00    |proj g|=  8.11257D-01
#
# At iterate   10    f= -2.42805D+00    |proj g|=  2.84783D-01
#
# At iterate   15    f= -2.42807D+00    |proj g|=  2.35877D-02
#
# At iterate   20    f= -2.42828D+00    |proj g|=  2.84325D-01
#
# At iterate   25    f= -2.42829D+00    |proj g|=  1.85159D-01
#
# At iterate   30    f= -2.42830D+00    |proj g|=  1.09200D-01
#
# At iterate   35    f= -2.42830D+00    |proj g|=  9.63558D-02
#
# At iterate   40    f= -2.42832D+00    |proj g|=  1.17161D-01
#
# At iterate   45    f= -2.42832D+00    |proj g|=  1.80921D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     45    112      2     0     0   1.809D-03  -2.428D+00
#   F =  -2.4283206234210089
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.42722D+00    |proj g|=  2.23014D+00
#
# At iterate    5    f= -2.42777D+00    |proj g|=  8.50942D-01
#
# At iterate   10    f= -2.43182D+00    |proj g|=  8.11484D-02
#
# At iterate   15    f= -2.43183D+00    |proj g|=  1.43982D-02
#
# At iterate   20    f= -2.43201D+00    |proj g|=  3.25690D-02
#
# At iterate   25    f= -2.43204D+00    |proj g|=  8.73212D-02
#   ys=-4.707E-09  -gs= 6.424E-09 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# 2014-12-30 05:00:00
# 6 : predicted = [0.4  0.55 0.67] expected = [0.40823634735899716, 0.5689346463742166, 0.6799462846911368]
# 2014-12-30 06:00:00
# 7 : predicted = [0.57 0.68 0.75] expected = [0.5689346463742166, 0.6799462846911368, 0.7309758281110115]
# 2014-12-30 07:00:00
# 8 : predicted = [0.68 0.75 0.8 ] expected = [0.6799462846911368, 0.7309758281110115, 0.7511190689346463]
# 2014-12-30 08:00:00
# 9 : predicted = [0.75 0.8  0.82] expected = [0.7309758281110115, 0.7511190689346463, 0.7636526410026856]
# 2014-12-30 09:00:00
# 10 : predicted = [0.76 0.78 0.78] expected = [0.7511190689346463, 0.7636526410026856, 0.7381378692927483]
# 2014-12-30 10:00:00
# 11 : predicted = [0.76 0.75 0.74] expected = [0.7636526410026856, 0.7381378692927483, 0.7188898836168307]
# 2014-12-30 11:00:00
# 12 : predicted = [0.77 0.76 0.75] expected = [0.7381378692927483, 0.7188898836168307, 0.7090420769919425]
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     30     89      2     1     0   3.951D-03  -2.432D+00
#   F =  -2.4320398031262540
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.45302D+00    |proj g|=  2.36751D-01
#
# At iterate    5    f= -2.45313D+00    |proj g|=  8.76462D-01
#
# At iterate   10    f= -2.45592D+00    |proj g|=  4.47503D-01
#
# At iterate   15    f= -2.45594D+00    |proj g|=  1.26598D-02
#
# At iterate   20    f= -2.45596D+00    |proj g|=  1.20783D-02
#
# At iterate   25    f= -2.45604D+00    |proj g|=  4.64595D-01
#
# At iterate   30    f= -2.45606D+00    |proj g|=  2.78173D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     30     43      1     0     0   2.782D-02  -2.456D+00
#   F =  -2.4560649353280404
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.45817D+00    |proj g|=  8.10715D-01
#
# At iterate    5    f= -2.45832D+00    |proj g|=  7.32754D-01
#
# At iterate   10    f= -2.46102D+00    |proj g|=  1.21150D+00
#
# At iterate   15    f= -2.46116D+00    |proj g|=  1.42844D-01
#
# At iterate   20    f= -2.46125D+00    |proj g|=  8.46020D-02
#
# At iterate   25    f= -2.46128D+00    |proj g|=  1.75218D-02
#
# At iterate   30    f= -2.46128D+00    |proj g|=  2.13650D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     48      1     0     0   1.970D-02  -2.461D+00
#   F =  -2.4612775225267258
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.46194D+00    |proj g|=  1.17532D+00
#
# At iterate    5    f= -2.46261D+00    |proj g|=  1.33335D+00
#
# At iterate   10    f= -2.46467D+00    |proj g|=  1.10162D-02
#
# At iterate   15    f= -2.46477D+00    |proj g|=  2.01791D-01
#
# At iterate   20    f= -2.46477D+00    |proj g|=  4.49029D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     44      1     0     0   2.650D-02  -2.465D+00
#   F =  -2.4647699840803807
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47439D+00    |proj g|=  2.05841D+00
#
# At iterate    5    f= -2.47481D+00    |proj g|=  3.87015D-01
#
# At iterate   10    f= -2.47689D+00    |proj g|=  1.87196D-01
#
# At iterate   15    f= -2.47695D+00    |proj g|=  1.54735D-02
#
# At iterate   20    f= -2.47696D+00    |proj g|=  5.45145D-02
#
# At iterate   25    f= -2.47696D+00    |proj g|=  1.55436D-01
#
# At iterate   30    f= -2.47697D+00    |proj g|=  4.01958D-02
#
# At iterate   35    f= -2.47697D+00    |proj g|=  3.19662D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     36     55      1     0     0   2.726D-02  -2.477D+00
#   F =  -2.4769671344938269
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47407D+00    |proj g|=  1.97382D+00
#
# At iterate    5    f= -2.47448D+00    |proj g|=  8.05814D-01
#
# At iterate   10    f= -2.47668D+00    |proj g|=  2.30294D-02
#
# At iterate   15    f= -2.47668D+00    |proj g|=  2.89312D-02
#
# At iterate   20    f= -2.47669D+00    |proj g|=  1.59342D-02
#
# At iterate   25    f= -2.47674D+00    |proj g|=  7.70583D-03
#
# At iterate   30    f= -2.47676D+00    |proj g|=  8.58813D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     30     61      1     0     0   8.588D-03  -2.477D+00
#   F =  -2.4767569523743291
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47425D+00    |proj g|=  1.98710D+00
#
# At iterate    5    f= -2.47465D+00    |proj g|=  4.22138D-01
#
# At iterate   10    f= -2.47675D+00    |proj g|=  1.27309D+00
#
# At iterate   15    f= -2.47693D+00    |proj g|=  3.38002D-02
#
# At iterate   20    f= -2.47699D+00    |proj g|=  1.98553D-02
#   ys=-1.435E-07  -gs= 1.710E-07 BFGS update SKIPPED
#   ys=-6.155E-10  -gs= 6.221E-10 BFGS update SKIPPED
#
# At iterate   25    f= -2.47699D+00    |proj g|=  1.50462D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     25     92      2     2     0   1.505D-02  -2.477D+00
#   F =  -2.4769875441129789
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47264D+00    |proj g|=  1.96959D+00
#
# At iterate    5    f= -2.47302D+00    |proj g|=  3.73010D-01
#
# At iterate   10    f= -2.47526D+00    |proj g|=  2.24601D-01
#   ys=-5.561E-11  -gs= 8.940E-11 BFGS update SKIPPED
#
# At iterate   15    f= -2.47527D+00    |proj g|=  2.95711D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# 2014-12-30 12:00:00
# 13 : predicted = [0.7  0.68 0.69] expected = [0.7188898836168307, 0.7090420769919425, 0.7081468218442255]
# 2014-12-30 13:00:00
# 14 : predicted = [0.72 0.73 0.76] expected = [0.7090420769919425, 0.7081468218442255, 0.7385854968666068]
# 2014-12-30 14:00:00
# 15 : predicted = [0.71 0.73 0.86] expected = [0.7081468218442255, 0.7385854968666068, 0.8478066248880931]
# 2014-12-30 15:00:00
# 16 : predicted = [0.73 0.85 0.97] expected = [0.7385854968666068, 0.8478066248880931, 0.9516562220232765]
# 2014-12-30 16:00:00
# 17 : predicted = [0.87 0.99 0.97] expected = [0.8478066248880931, 0.9516562220232765, 0.934198746642793]
# 2014-12-30 17:00:00
# 18 : predicted = [0.94 0.92 0.86] expected = [0.9516562220232765, 0.934198746642793, 0.8876454789615038]
# 2014-12-30 18:00:00
# 19 : predicted = [0.94 0.89 0.82] expected = [0.934198746642793, 0.8876454789615038, 0.8294538943598924]
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     58      2     1     0   2.957D-02  -2.475D+00
#   F =  -2.4752715922013340
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47219D+00    |proj g|=  2.02081D+00
#
# At iterate    5    f= -2.47261D+00    |proj g|=  4.73742D-01
#
# At iterate   10    f= -2.47450D+00    |proj g|=  2.29031D+00
#
# At iterate   15    f= -2.47503D+00    |proj g|=  2.49963D-02
#
# At iterate   20    f= -2.47506D+00    |proj g|=  1.02380D-02
#
# At iterate   25    f= -2.47508D+00    |proj g|=  4.68464D-02
#
# At iterate   30    f= -2.47511D+00    |proj g|=  1.24977D-01
#
# At iterate   35    f= -2.47512D+00    |proj g|=  1.51104D-03
#   ys=-7.043E-14  -gs= 8.875E-12 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     37    102      3     1     0   2.868D-03  -2.475D+00
#   F =  -2.4751162115394152
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47247D+00    |proj g|=  2.06965D+00
#
# At iterate    5    f= -2.47290D+00    |proj g|=  4.16108D-01
#
# At iterate   10    f= -2.47463D+00    |proj g|=  2.51081D+00
#
# At iterate   15    f= -2.47534D+00    |proj g|=  2.14054D-02
#
# At iterate   20    f= -2.47536D+00    |proj g|=  2.51987D-01
#
# At iterate   25    f= -2.47539D+00    |proj g|=  5.32646D-02
#
# At iterate   30    f= -2.47542D+00    |proj g|=  1.68820D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     62      1     0     0   2.585D-03  -2.475D+00
#   F =  -2.4754228515156296
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47262D+00    |proj g|=  1.65968D+00
#
# At iterate    5    f= -2.47310D+00    |proj g|=  1.27557D+00
#
# At iterate   10    f= -2.47547D+00    |proj g|=  1.73570D-01
#
# At iterate   15    f= -2.47548D+00    |proj g|=  8.82924D-02
#
# At iterate   20    f= -2.47555D+00    |proj g|=  2.72116D-02
#
# At iterate   25    f= -2.47556D+00    |proj g|=  5.20182D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     29     51      1     0     0   3.000D-02  -2.476D+00
#   F =  -2.4755572530654515
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47454D+00    |proj g|=  1.83674D+00
#
# At iterate    5    f= -2.47490D+00    |proj g|=  4.93276D-01
#
# At iterate   10    f= -2.47727D+00    |proj g|=  7.94168D-02
#
# At iterate   15    f= -2.47728D+00    |proj g|=  8.02080D-02
#
# At iterate   20    f= -2.47731D+00    |proj g|=  1.13721D-01
#
# At iterate   25    f= -2.47733D+00    |proj g|=  1.97489D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     47      1     0     0   4.032D-03  -2.477D+00
#   F =  -2.4773304985002200
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47496D+00    |proj g|=  1.95433D+00
#
# At iterate    5    f= -2.47533D+00    |proj g|=  3.53151D-01
#
# At iterate   10    f= -2.47762D+00    |proj g|=  3.51573D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     25      1     0     0   1.600D-02  -2.478D+00
#   F =  -2.4776329110025097
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47581D+00    |proj g|=  1.98036D+00
#
# At iterate    5    f= -2.47620D+00    |proj g|=  5.00051D-01
#
# At iterate   10    f= -2.47798D+00    |proj g|=  1.87260D+00
#
# At iterate   15    f= -2.47832D+00    |proj g|=  2.02617D-02
#
# At iterate   20    f= -2.47836D+00    |proj g|=  1.13321D-01
#
# At iterate   25    f= -2.47839D+00    |proj g|=  1.48122D-01
#   ys=-1.406E-07  -gs= 4.940E-07 BFGS update SKIPPED
#
# At iterate   30    f= -2.47839D+00    |proj g|=  2.15707D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     92      2     1     0   2.157D-02  -2.478D+00
#   F =  -2.4783935691775700
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47585D+00    |proj g|=  1.98205D+00
#
# At iterate    5    f= -2.47623D+00    |proj g|=  3.87512D-01
#
# At iterate   10    f= -2.47815D+00    |proj g|=  1.53608D+00
#
# At iterate   15    f= -2.47836D+00    |proj g|=  7.04726D-03
#
# At iterate   20    f= -2.47842D+00    |proj g|=  3.50326D-02
#
# At iterate   25    f= -2.47842D+00    |proj g|=  1.53690D-02
#
# At iterate   30    f= -2.47843D+00    |proj g|=  7.51728D-02
#
# At iterate   35    f= -2.47843D+00    |proj g|=  2.39526D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
# 2014-12-30 19:00:00
# 20 : predicted = [0.88 0.82 0.71] expected = [0.8876454789615038, 0.8294538943598924, 0.7197851387645477]
# 2014-12-30 20:00:00
# 21 : predicted = [0.83 0.72 0.58] expected = [0.8294538943598924, 0.7197851387645477, 0.5747538048343777]
# 2014-12-30 21:00:00
# 22 : predicted = [0.72 0.58 0.47] expected = [0.7197851387645477, 0.5747538048343777, 0.4592658907788718]
# 2014-12-30 22:00:00
# 23 : predicted = [0.58 0.47 0.39] expected = [0.5747538048343777, 0.4592658907788718, 0.3858549686660697]
# 2014-12-30 23:00:00
# 24 : predicted = [0.46 0.38 0.34] expected = [0.4592658907788718, 0.3858549686660697, 0.34377797672336596]
# 2014-12-31 00:00:00
# 25 : predicted = [0.38 0.34 0.33] expected = [0.3858549686660697, 0.34377797672336596, 0.32542524619516544]
# 2014-12-31 01:00:00
# 26 : predicted = [0.36 0.34 0.34] expected = [0.34377797672336596, 0.32542524619516544, 0.33034914950760963]
# 2014-12-31 02:00:00
# 27 : predicted = [0.32 0.32 0.35] expected = [0.32542524619516544, 0.33034914950760963, 0.3706356311548791]
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     36     80      2     0     0   2.386D-02  -2.478D+00
#   F =  -2.4784307248343467
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47584D+00    |proj g|=  1.98236D+00
#
# At iterate    5    f= -2.47623D+00    |proj g|=  4.02650D-01
#
# At iterate   10    f= -2.47793D+00    |proj g|=  2.01582D+00
#
# At iterate   15    f= -2.47835D+00    |proj g|=  9.20296D-03
#
# At iterate   20    f= -2.47842D+00    |proj g|=  9.10597D-03
#   ys=-3.331E-08  -gs= 1.330E-08 BFGS update SKIPPED
#   ys=-2.114E-10  -gs= 4.101E-09 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     90      2     2     0   1.097D-02  -2.478D+00
#   F =  -2.4784221535293800
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47613D+00    |proj g|=  2.01164D+00
#
# At iterate    5    f= -2.47652D+00    |proj g|=  3.69953D-01
#
# At iterate   10    f= -2.47819D+00    |proj g|=  2.07743D+00
#
# At iterate   15    f= -2.47866D+00    |proj g|=  6.19019D-02
#   ys=-1.384E-09  -gs= 2.078E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     47      1     1     0   8.538D-03  -2.479D+00
#   F =  -2.4786601159257056
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47619D+00    |proj g|=  2.01926D+00
#
# At iterate    5    f= -2.47660D+00    |proj g|=  4.20837D-01
#
# At iterate   10    f= -2.47836D+00    |proj g|=  1.87143D+00
#
# At iterate   15    f= -2.47874D+00    |proj g|=  3.25284D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     38      1     0     0   3.253D-02  -2.479D+00
#   F =  -2.4787379948427168
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47623D+00    |proj g|=  2.02380D+00
#
# At iterate    5    f= -2.47664D+00    |proj g|=  4.33158D-01
#
# At iterate   10    f= -2.47844D+00    |proj g|=  1.84525D+00
#
# At iterate   15    f= -2.47879D+00    |proj g|=  1.37505D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     25      1     0     0   2.245D-02  -2.479D+00
#   F =  -2.4787905706626328
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47622D+00    |proj g|=  2.02204D+00
#
# At iterate    5    f= -2.47663D+00    |proj g|=  5.29247D-01
#
# At iterate   10    f= -2.47872D+00    |proj g|=  9.65356D-01
#
# At iterate   15    f= -2.47882D+00    |proj g|=  3.93581D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     27      1     0     0   3.936D-02  -2.479D+00
#   F =  -2.4788182731227204
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47614D+00    |proj g|=  2.00057D+00
#
# At iterate    5    f= -2.47653D+00    |proj g|=  3.90038D-01
#
# At iterate   10    f= -2.47865D+00    |proj g|=  2.05423D-01
#
# At iterate   15    f= -2.47872D+00    |proj g|=  3.09232D-01
#
# At iterate   20    f= -2.47875D+00    |proj g|=  7.96206D-02
#
# At iterate   25    f= -2.47876D+00    |proj g|=  1.71632D-02
#
# At iterate   30    f= -2.47876D+00    |proj g|=  4.86154D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     34     55      1     0     0   4.049D-02  -2.479D+00
#   F =  -2.4787652040271091
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47614D+00    |proj g|=  1.99668D+00
#
# At iterate    5    f= -2.47653D+00    |proj g|=  3.93697D-01
#
# At iterate   10    f= -2.47810D+00    |proj g|=  2.35091D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     24      1     0     0   1.295D-02  -2.479D+00
#   F =  -2.4786782293991099
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47671D+00    |proj g|=  1.93928D+00
#
# At iterate    5    f= -2.47708D+00    |proj g|=  3.98753D-01
#
# At iterate   10    f= -2.47876D+00    |proj g|=  1.94943D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# 2014-12-31 03:00:00
# 28 : predicted = [0.32 0.36 0.47] expected = [0.33034914950760963, 0.3706356311548791, 0.470008952551477]
# 2014-12-31 04:00:00
# 29 : predicted = [0.37 0.48 0.65] expected = [0.3706356311548791, 0.470008952551477, 0.6145926589077886]
# 2014-12-31 05:00:00
# 30 : predicted = [0.48 0.64 0.75] expected = [0.470008952551477, 0.6145926589077886, 0.7247090420769919]
# 2014-12-31 06:00:00
# 31 : predicted = [0.63 0.73 0.79] expected = [0.6145926589077886, 0.7247090420769919, 0.786034019695613]
# 2014-12-31 07:00:00
# 32 : predicted = [0.71 0.76 0.79] expected = [0.7247090420769919, 0.786034019695613, 0.8012533572068039]
# 2014-12-31 08:00:00
# 33 : predicted = [0.79 0.82 0.83] expected = [0.786034019695613, 0.8012533572068039, 0.7994628469113696]
# 2014-12-31 09:00:00
# 34 : predicted = [0.82 0.83 0.81] expected = [0.8012533572068039, 0.7994628469113696, 0.780214861235452]
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     30      1     0     0   9.962D-03  -2.479D+00
#   F =  -2.4791541653480071
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47680D+00    |proj g|=  1.96853D+00
#
# At iterate    5    f= -2.47719D+00    |proj g|=  4.66295D-01
#
# At iterate   10    f= -2.47926D+00    |proj g|=  2.34050D-01
#
# At iterate   15    f= -2.47931D+00    |proj g|=  7.49796D-02
#
# At iterate   20    f= -2.47933D+00    |proj g|=  4.41665D-03
#
# At iterate   25    f= -2.47934D+00    |proj g|=  2.99014D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     26     53      1     0     0   9.171D-03  -2.479D+00
#   F =  -2.4793397771635459
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47675D+00    |proj g|=  1.91395D+00
#
# At iterate    5    f= -2.47711D+00    |proj g|=  3.61730D-01
#
# At iterate   10    f= -2.47902D+00    |proj g|=  1.62981D+00
#
# At iterate   15    f= -2.47932D+00    |proj g|=  2.06799D-01
#
# At iterate   20    f= -2.47935D+00    |proj g|=  5.25844D-02
#
# At iterate   25    f= -2.47935D+00    |proj g|=  1.48264D-02
#   ys=-3.539E-10  -gs= 5.567E-10 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     29     68      1     1     0   2.149D-03  -2.479D+00
#   F =  -2.4793534249264764
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47691D+00    |proj g|=  1.93197D+00
#
# At iterate    5    f= -2.47728D+00    |proj g|=  3.70835D-01
#
# At iterate   10    f= -2.47895D+00    |proj g|=  2.09978D+00
#
# At iterate   15    f= -2.47937D+00    |proj g|=  2.98327D-02
#
# At iterate   20    f= -2.47938D+00    |proj g|=  6.81428D-02
#
# At iterate   25    f= -2.47938D+00    |proj g|=  1.36665D-01
#
# At iterate   30    f= -2.47942D+00    |proj g|=  1.32653D-01
#   ys=-3.432E-11  -gs= 8.257E-11 BFGS update SKIPPED
#
# At iterate   35    f= -2.47942D+00    |proj g|=  8.82987D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     36    103      2     1     0   8.830D-03  -2.479D+00
#   F =  -2.4794194438122403
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47673D+00    |proj g|=  1.92357D+00
#
# At iterate    5    f= -2.47709D+00    |proj g|=  3.69843D-01
#
# At iterate   10    f= -2.47890D+00    |proj g|=  1.78557D+00
#
# At iterate   15    f= -2.47921D+00    |proj g|=  1.03250D-02
#
# At iterate   20    f= -2.47927D+00    |proj g|=  2.42696D-02
#
# At iterate   25    f= -2.47928D+00    |proj g|=  2.72771D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     44      1     0     0   2.078D-02  -2.479D+00
#   F =  -2.4792847357590584
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47694D+00    |proj g|=  1.78907D+00
#
# At iterate    5    f= -2.47726D+00    |proj g|=  3.42296D-01
#
# At iterate   10    f= -2.47877D+00    |proj g|=  2.15841D+00
#
# At iterate   15    f= -2.47930D+00    |proj g|=  7.82688D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     40      1     0     0   8.761D-03  -2.479D+00
#   F =  -2.4793575714945191
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47736D+00    |proj g|=  1.79643D+00
#
# At iterate    5    f= -2.47768D+00    |proj g|=  4.18086D-01
#
# At iterate   10    f= -2.47916D+00    |proj g|=  2.33302D+00
#
# At iterate   15    f= -2.47972D+00    |proj g|=  1.89601D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     31      1     0     0   2.239D-02  -2.480D+00
#   F =  -2.4797161131854035
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47794D+00    |proj g|=  1.89004D+00
#
# At iterate    5    f= -2.47828D+00    |proj g|=  3.26552D-01
#
# At iterate   10    f= -2.48037D+00    |proj g|=  2.65626D-01
#
# At iterate   15    f= -2.48038D+00    |proj g|=  7.57945D-02
#
# At iterate   20    f= -2.48038D+00    |proj g|=  1.50598D-02
#
# At iterate   25    f= -2.48039D+00    |proj g|=  1.20190D-02
#
# At iterate   30    f= -2.48039D+00    |proj g|=  3.42554D-02
#
# At iterate   35    f= -2.48039D+00    |proj g|=  2.70563D-02
#
# At iterate   40    f= -2.48040D+00    |proj g|=  1.09325D-01
#
# At iterate   45    f= -2.48040D+00    |proj g|=  1.14261D-01
#
# At iterate   50    f= -2.48041D+00    |proj g|=  9.45204D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
# 2014-12-31 10:00:00
# 35 : predicted = [0.8  0.78 0.76] expected = [0.7994628469113696, 0.780214861235452, 0.7587287376902416]
# 2014-12-31 11:00:00
# 36 : predicted = [0.77 0.75 0.74] expected = [0.780214861235452, 0.7587287376902416, 0.7367949865711727]
# 2014-12-31 12:00:00
# 37 : predicted = [0.77 0.76 0.76] expected = [0.7587287376902416, 0.7367949865711727, 0.7188898836168307]
# 2014-12-31 13:00:00
# 38 : predicted = [0.75 0.75 0.78] expected = [0.7367949865711727, 0.7188898836168307, 0.7273948075201431]
# 2014-12-31 14:00:00
# 39 : predicted = [0.73 0.75 0.87] expected = [0.7188898836168307, 0.7273948075201431, 0.8299015219337511]
# 2014-12-31 15:00:00
# 40 : predicted = [0.74 0.85 0.96] expected = [0.7273948075201431, 0.8299015219337511, 0.909579230080573]
# 2014-12-31 16:00:00
# 41 : predicted = [0.83 0.94 0.93] expected = [0.8299015219337511, 0.909579230080573, 0.855863921217547]
# 2014-12-31 17:00:00
# 42 : predicted = [0.94 0.93 0.88] expected = [0.909579230080573, 0.855863921217547, 0.7721575649059982]
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     87      1     0     0   9.452D-02  -2.480D+00
#   F =  -2.4804072486448074
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47788D+00    |proj g|=  1.87734D+00
#
# At iterate    5    f= -2.47824D+00    |proj g|=  6.31582D-01
#
# At iterate   10    f= -2.48032D+00    |proj g|=  2.39863D-01
#
# At iterate   15    f= -2.48039D+00    |proj g|=  7.42490D-02
#
# At iterate   20    f= -2.48039D+00    |proj g|=  1.17237D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     22     44      1     0     0   2.438D-02  -2.480D+00
#   F =  -2.4803931667753645
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47767D+00    |proj g|=  1.89557D+00
#
# At iterate    5    f= -2.47816D+00    |proj g|=  7.34896D-01
#
# At iterate   10    f= -2.48016D+00    |proj g|=  1.07511D-02
#
# At iterate   15    f= -2.48025D+00    |proj g|=  9.73755D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     31      1     0     0   5.947D-02  -2.480D+00
#   F =  -2.4802578648469584
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47794D+00    |proj g|=  1.87254D+00
#
# At iterate    5    f= -2.47829D+00    |proj g|=  3.60899D-01
#
# At iterate   10    f= -2.48044D+00    |proj g|=  7.26002D-01
#
# At iterate   15    f= -2.48049D+00    |proj g|=  3.55952D-02
#
# At iterate   20    f= -2.48051D+00    |proj g|=  3.80858D-01
#
# At iterate   25    f= -2.48056D+00    |proj g|=  6.11250D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     96      2     0     0   2.174D-02  -2.481D+00
#   F =  -2.4805622000564371
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47799D+00    |proj g|=  1.88498D+00
#
# At iterate    5    f= -2.47834D+00    |proj g|=  4.08661D-01
#
# At iterate   10    f= -2.48002D+00    |proj g|=  2.10586D+00
#
# At iterate   15    f= -2.48054D+00    |proj g|=  1.07670D-02
#
# At iterate   20    f= -2.48063D+00    |proj g|=  4.27822D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     33      1     0     0   1.337D-01  -2.481D+00
#   F =  -2.4806336629691561
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47785D+00    |proj g|=  1.77092D+00
#
# At iterate    5    f= -2.47819D+00    |proj g|=  6.35568D-01
#
# At iterate   10    f= -2.48040D+00    |proj g|=  3.74495D-01
#
# At iterate   15    f= -2.48042D+00    |proj g|=  1.84065D-01
#
# At iterate   20    f= -2.48047D+00    |proj g|=  7.81449D-02
#
# At iterate   25    f= -2.48049D+00    |proj g|=  3.13811D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     27     52      1     0     0   6.881D-03  -2.480D+00
#   F =  -2.4804859739245986
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47838D+00    |proj g|=  1.83840D+00
#
# At iterate    5    f= -2.47873D+00    |proj g|=  5.94659D-01
#
# At iterate   10    f= -2.48085D+00    |proj g|=  7.08099D-01
#
# At iterate   15    f= -2.48096D+00    |proj g|=  1.32016D-02
#   ys=-4.838E-07  -gs= 7.362E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     19     38      1     1     0   5.289D-03  -2.481D+00
#   F =  -2.4810005186268973
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47906D+00    |proj g|=  1.91053D+00
#
# At iterate    5    f= -2.47942D+00    |proj g|=  3.82794D-01
#
# At iterate   10    f= -2.48168D+00    |proj g|=  1.05580D-02
#
# At iterate   15    f= -2.48172D+00    |proj g|=  2.66348D-01
#
# At iterate   20    f= -2.48174D+00    |proj g|=  4.09691D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     23     76      2     0     0   1.698D-02  -2.482D+00
#   F =  -2.4817522448107634
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.47776D+00    |proj g|=  1.89886D+00
#
# At iterate    5    f= -2.47814D+00    |proj g|=  5.15837D-01
#
# At iterate   10    f= -2.48037D+00    |proj g|=  1.13971D-02
#
# At iterate   15    f= -2.48048D+00    |proj g|=  8.37706D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# 2014-12-31 18:00:00
# 43 : predicted = [0.87 0.82 0.77] expected = [0.855863921217547, 0.7721575649059982, 0.7023276633840643]
# 2014-12-31 19:00:00
# 44 : predicted = [0.79 0.73 0.63] expected = [0.7721575649059982, 0.7023276633840643, 0.6195165622202325]
# 2014-12-31 20:00:00
# 45 : predicted = [0.7  0.59 0.46] expected = [0.7023276633840643, 0.6195165622202325, 0.5425246195165621]
# 2014-12-31 21:00:00
# 46 : predicted = [0.6  0.47 0.36] expected = [0.6195165622202325, 0.5425246195165621, 0.4735899731423454]
# CPU times: user 5min 58s, sys: 14min 9s, total: 20min 8s
# Wall time: 2min 43s

# %%
eval_df = pd.DataFrame(predictions, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
eval_df['timestamp'] = test.index[0:len(test.index)-HORIZON+1]
eval_df = pd.melt(eval_df, id_vars='timestamp', value_name='prediction', var_name='h')
eval_df['actual'] = np.array(np.transpose(test_ts)).ravel()
eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
eval_df.head()
# Out:
#             timestamp    h  prediction   actual
# 0 2014-12-30 00:00:00  t+1    3,008.68 3,023.00
# 1 2014-12-30 01:00:00  t+1    2,955.66 2,935.00
# 2 2014-12-30 02:00:00  t+1    2,900.16 2,899.00
# 3 2014-12-30 03:00:00  t+1    2,917.86 2,886.00
# 4 2014-12-30 04:00:00  t+1    2,946.78 2,963.00

# %%
if(HORIZON > 1):
    eval_df['APE'] = (eval_df['prediction'] - eval_df['actual']).abs() / eval_df['actual']
    print(eval_df.groupby('h')['APE'].mean())
# Out:
# h
# t+1   0.01
# t+2   0.01
# t+3   0.02
# Name: APE, dtype: float64

# %%
print('One step forecast MAPE: ', (mape(eval_df[eval_df['h'] == 't+1']['prediction'], eval_df[eval_df['h'] == 't+1']['actual']))*100, '%')
# Out:
# One step forecast MAPE:  0.5570306239793937 %

# %%
print('Multi-step forecast MAPE: ', mape(eval_df['prediction'], eval_df['actual'])*100, '%')
# Out:
# Multi-step forecast MAPE:  1.1466816595258953 %

# %%
if(HORIZON == 1):
    ## Plotting single step forecast
    eval_df.plot(x='timestamp', y=['actual', 'prediction'], style=['r', 'b'], figsize=(15, 8))

else:
    ## Plotting multi step forecast
    plot_df = eval_df[(eval_df.h=='t+1')][['timestamp', 'actual']]
    for t in range(1, HORIZON+1):
        plot_df['t+'+str(t)] = eval_df[(eval_df.h=='t+'+str(t))]['prediction'].values

    fig = plt.figure(figsize=(15, 8))
    ax = fig.add_subplot()
    plt.plot(plot_df['timestamp'], plot_df['actual'], color='red', linewidth=4.0)
    for t in range(1, HORIZON+1):
        x = plot_df['timestamp'][(t-1):]
        y = plot_df['t+'+str(t)][0:len(x)]
        ax.plot(x, y, color='blue', linewidth=4*math.pow(.9,t), alpha=math.pow(0.8,t))

    ax.legend(loc='best')

plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plot_df
# Out:
#              timestamp   actual      t+1      t+2      t+3
# 0  2014-12-30 00:00:00 3,023.00 3,008.68 2,929.01 2,907.55
# 1  2014-12-30 01:00:00 2,935.00 2,955.66 2,938.06 2,962.75
# 2  2014-12-30 02:00:00 2,899.00 2,900.16 2,920.04 3,008.29
# 3  2014-12-30 03:00:00 2,886.00 2,917.86 3,005.66 3,217.48
# 4  2014-12-30 04:00:00 2,963.00 2,946.78 3,150.93 3,492.85
# 5  2014-12-30 05:00:00 3,199.00 3,180.88 3,526.57 3,772.93
# 6  2014-12-30 06:00:00 3,558.00 3,558.90 3,809.12 3,963.48
# 7  2014-12-30 07:00:00 3,806.00 3,807.65 3,962.08 4,071.11
# 8  2014-12-30 08:00:00 3,920.00 3,959.17 4,068.00 4,113.21
# 9  2014-12-30 09:00:00 3,965.00 3,995.87 4,031.35 4,036.48
# 10 2014-12-30 10:00:00 3,993.00 3,974.39 3,971.70 3,939.33
# 11 2014-12-30 11:00:00 3,936.00 4,006.10 3,978.52 3,962.86
# 12 2014-12-30 12:00:00 3,893.00 3,849.76 3,816.66 3,828.84
# 13 2014-12-30 13:00:00 3,871.00 3,896.34 3,919.62 3,975.69
# 14 2014-12-30 14:00:00 3,869.00 3,873.07 3,922.97 4,205.03
# 15 2014-12-30 15:00:00 3,937.00 3,915.48 4,196.54 4,445.64
# 16 2014-12-30 16:00:00 4,181.00 4,236.09 4,490.81 4,450.37
# 17 2014-12-30 17:00:00 4,413.00 4,390.06 4,336.21 4,217.39
# 18 2014-12-30 18:00:00 4,374.00 4,378.37 4,265.64 4,124.01
# 19 2014-12-30 19:00:00 4,270.00 4,257.58 4,114.85 3,865.72
# 20 2014-12-30 20:00:00 4,140.00 4,137.68 3,891.60 3,578.60
# 21 2014-12-30 21:00:00 3,895.00 3,895.96 3,583.84 3,333.09
# 22 2014-12-30 22:00:00 3,571.00 3,582.01 3,330.96 3,149.22
# 23 2014-12-30 23:00:00 3,313.00 3,310.85 3,126.46 3,041.82
# 24 2014-12-31 00:00:00 3,149.00 3,130.40 3,046.33 3,015.66
# 25 2014-12-31 01:00:00 3,055.00 3,080.45 3,054.35 3,048.58
# 26 2014-12-31 02:00:00 3,014.00 3,007.79 2,996.00 3,078.30
# 27 2014-12-31 03:00:00 3,025.00 3,007.35 3,091.17 3,330.51
# 28 2014-12-31 04:00:00 3,115.00 3,123.67 3,367.42 3,729.83
# 29 2014-12-31 05:00:00 3,337.00 3,351.47 3,711.77 3,956.12
# 30 2014-12-31 06:00:00 3,660.00 3,685.00 3,925.71 4,044.81
# 31 2014-12-31 07:00:00 3,906.00 3,879.77 3,992.96 4,055.86
# 32 2014-12-31 08:00:00 4,043.00 4,040.99 4,110.03 4,143.88
# 33 2014-12-31 09:00:00 4,077.00 4,113.70 4,148.07 4,098.40
# 34 2014-12-31 10:00:00 4,073.00 4,080.63 4,021.76 3,976.58
# 35 2014-12-31 11:00:00 4,030.00 4,007.67 3,960.61 3,945.74
# 36 2014-12-31 12:00:00 3,982.00 4,001.66 3,992.34 3,994.93
# 37 2014-12-31 13:00:00 3,933.00 3,956.15 3,953.91 4,018.86
# 38 2014-12-31 14:00:00 3,893.00 3,911.30 3,970.46 4,226.39
# 39 2014-12-31 15:00:00 3,912.00 3,936.73 4,187.87 4,435.93
# 40 2014-12-31 16:00:00 4,141.00 4,142.48 4,384.52 4,359.45
# 41 2014-12-31 17:00:00 4,319.00 4,381.91 4,356.64 4,258.24
# 42 2014-12-31 18:00:00 4,199.00 4,240.86 4,127.01 4,006.44
# 43 2014-12-31 19:00:00 4,012.00 4,049.54 3,918.02 3,692.32
# 44 2014-12-31 20:00:00 3,856.00 3,848.52 3,612.41 3,311.70
# 45 2014-12-31 21:00:00 3,671.00 3,626.18 3,327.38 3,082.31

# %%
eval_df
# Out:
#               timestamp    h  prediction   actual  APE
# 0   2014-12-30 00:00:00  t+1    3,008.68 3,023.00 0.00
# 1   2014-12-30 01:00:00  t+1    2,955.66 2,935.00 0.01
# 2   2014-12-30 02:00:00  t+1    2,900.16 2,899.00 0.00
# 3   2014-12-30 03:00:00  t+1    2,917.86 2,886.00 0.01
# 4   2014-12-30 04:00:00  t+1    2,946.78 2,963.00 0.01
# ..                  ...  ...         ...      ...  ...
# 133 2014-12-31 17:00:00  t+3    4,258.24 4,012.00 0.06
# 134 2014-12-31 18:00:00  t+3    4,006.44 3,856.00 0.04
# 135 2014-12-31 19:00:00  t+3    3,692.32 3,671.00 0.01
# 136 2014-12-31 20:00:00  t+3    3,311.70 3,499.00 0.05
# 137 2014-12-31 21:00:00  t+3    3,082.31 3,345.00 0.08
#
# [138 rows x 5 columns]
