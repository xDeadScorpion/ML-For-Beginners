# %% [markdown]
# # Peter and the Wolf: Reinforcement Learning Primer
#
# In this tutorial, we will learn how to apply Reinforcement learning to a problem of path finding. The setting is inspired by [Peter and the Wolf](https://en.wikipedia.org/wiki/Peter_and_the_Wolf) musical fairy tale by Russian composer [Sergei Prokofiev](https://en.wikipedia.org/wiki/Sergei_Prokofiev). It is a story about young pioneer Peter, who bravely goes out of his house to the forest clearing to chase a wolf. We will train machine learning algorithms that will help Peter to explore the surrounding area and build an optimal navigation map.
#
# First, let's import a bunch of useful libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math

# %% [markdown]
# ## Overview of Reinforcement Learning
#
# **Reinforcement Learning** (RL) is a learning technique that allows us to learn an optimal behaviour of an **agent** in some **environment** by running many experiments. An agent in this environment should have some **goal**, defined by a **reward function**.
#
# ## The Environment
#
# For simplicity, let's consider Peter's world to be a square board of size `width` x `height`. Each cell in this board can either be:
# * **ground**, on which Peter and other creatures can walk
# * **water**, on which you obviously cannot walk
# * **a tree** or **grass** - a place where you can rest
# * **an apple**, which represents something Peter would be glad to find in order to feed himself
# * **a wolf**, which is dangerous and should be avoided
#
# To work with the environment, we will define a class called `Board`. In order not to clutter this notebook too much, we have moved all code to work with the board into separate `rlboard` module, which we will now import. You may look inside this module to get more details about the internals of the implementation.

# %% [markdown]
# Let's now create a random board and see how it looks:

# %%
# code block 1
from rlboard import *
width, height = 8, 8
m = Board(width, height)
m.randomize(seed=13)
m.plot()

# %% [markdown]
# ## Actions and Policy
#
# In our example, Peter's goal would be to find an apple, while avoiding the wolf and other obstacles. Define those actions as a dictionary, and map them to pairs of corresponding coordinate changes.

# %%
# code block 2
actions = {'U':(0,-1), 'D':(0,1), 'L':(-1,0), 'R':(1,0)}
action_idx = {a:i for i, a in enumerate(actions.keys())}

# %%
class state():
    def __init__(self, energyStart=10, energyBonus=5, energyNeededToKill=3) -> None:
        self.energy = energyStart
        self.energyRest = energyStart
        self.energyBonus = energyBonus
        self.energyNeededToKill = energyNeededToKill
        return

    def move(self) -> None:
        self.energy -= 1
        return

    def is_alive(self) -> bool:
        if self.energy <= 0:
            return False
        else:
            return True

    def rest(self) -> None:
        if self.energy >= self.energyRest:
            return
        else:
            self.energy = self.energyRest
            return

    def add_energy(self, energyBonus=None) -> None:
        if energyBonus is None:
            energyBonus = self.energyBonus

        self.energy += energyBonus
        return

    def can_kill(self, energyNeededToKill=None) -> bool:
        if energyNeededToKill is None:
            energyNeededToKill = self.energyNeededToKill

        if self.energy >= energyNeededToKill:
            return True
        else:
            return False

# %% [markdown]
# The strategy of our agent (Peter) is defined by a so-called **policy**. Let's consider the simplest policy called **random walk**.
#
# ## Random walk
#
# Let's first solve our problem by implementing a random walk strategy.

# %%
# Let's run a random walk experiment several times and see the average number of steps taken: code block 3
def random_policy(m):
    return random.choice(list(actions))

def walk(m, policy, start_position=None):
    n = 0  # number of steps
    s = state()
    # set initial position
    if start_position:
        m.human = start_position
    else:
        m.random_start()

    while True:
        if m.at() == Board.Cell.apple:
            s.add_energy()
        if m.at() == Board.Cell.wolf:
            if s.can_kill():
                return n
            else:
                return -1  # eaten by wolf
        if m.at() == Board.Cell.water:
            return -1  # fell in water
        any_valid_posions = 0  # infinite loop protection
        while True:
            a = actions[policy(m)]
            new_pos = m.move_pos(m.human, a)
            if m.is_valid(new_pos) and m.at(new_pos) != Board.Cell.water:
                m.move(a)
                break
            if any_valid_posions >= 100:
                return -1  # no valid positions can be found
            any_valid_posions += 1
        n += 1
        # if n >= 100:
        #     return -1  # died by too many moves


walk(m, random_policy)
# Out:
# 1046

# %%
# code block 4
def print_statistics(policy):
    s, w, n = 0, 0, 0
    for _ in range(100):
        z = walk(m, policy)
        if z < 0:
            w += 1
        else:
            s += z
            n += 1
    print(f'Average path length = {s/n}, eaten by wolf: {w} times')

print_statistics(random_policy)
# Out:
# Average path length = 362.63, eaten by wolf: 0 times

# %% [markdown]
# ## Reward Function
#
# To make our policy more intelligent, we need to understand which moves are "better" than others.

# %%
#code block 5
move_reward = -0.1
goal_reward = 10
end_reward = 10

def reward(m, pos=None):
    pos = pos or m.human
    if not m.is_valid(pos):
        return end_reward
    x = m.at(pos)
    if x == Board.Cell.water or x == Board.Cell.wolf:
        return end_reward
    if x== Board.Cell.apple:
        return goal_reward
    return move_reward

# %% [markdown]
# ## Q-Learning
#
# Build a Q-Table, or multi-dimensional array. Since our board has dimentions `width` x `height`, we can represent Q-Table by a numpy array with shape `width` x `height` x `len(actions)`:

# %%
# code block 6
Q = np.ones((width, height, len(actions)), dtype=np.float) * 1.0/len(actions)

# %% [markdown]
# Pass the Q-Table to the `plot` function in order to visualize the table on the board:

# %%
m.plot(Q)

# %% [markdown]
# ## Essence of Q-Learning: Bellman Equation and  Learning Algorithm
#
# Write a pseudo-code for our leaning algorithm:
#
# * Initialize Q-Table Q with equal numbers for all states and actions
# * Set learning rate $\alpha\leftarrow 1$
# * Repeat simulation many times
#    1. Start at random position
#    1. Repeat
#         1. Select an action $a$ at state $s$
#         2. Exectute action by moving to a new state $s'$
#         3. If we encounter end-of-game condition, or total reward is too small - exit simulation
#         4. Compute reward $r$ at the new state
#         5. Update Q-Function according to Bellman equation: $Q(s,a)\leftarrow (1-\alpha)Q(s,a)+\alpha(r+\gamma\max_{a'}Q(s',a'))$
#         6. $s\leftarrow s'$
#         7. Update total reward and decrease $\alpha$.
#
# ## Exploit vs. Explore
#
# The best approach is to balance between exploration and exploitation. As we learn more about our environment, we would be more likely to follow the optimal route, however, choosing the unexplored path once in a while.
#
# ## Python Implementation
#
# Now we are ready to implement the learning algorithm. Before that, we also need some function that will convert arbitrary numbers in the Q-Table into a vector of probabilities for corresponding actions:

# %%
# code block 7
def probs(v, eps=1e-4):
    v = v - v.min() + eps
    v = v / v.sum()
    return v

# %% [markdown]
# We add a small amount of `eps` to the original vector in order to avoid division by 0 in the initial case, when all components of the vector are identical.
#
# The actual learning algorithm we will run for 5000 experiments, also called **epochs**:

# %%
from IPython.display import clear_output

lpath = []

# code block 8
for epoch in range(int(1e5)):
    # Pick initial point
    m.random_start()

    # Start travelling
    n=0
    cum_reward = 0
    while True:
        x, y = m.human
        v = probs(Q[x, y])
        a = random.choices(list(actions), weights=v)[0]
        dpos = actions[a]
        m.move(dpos, check_correctness=False)  # we allow player to move outside the board, which terminates episode
        r = reward(m)
        cum_reward += r
        if r == end_reward or cum_reward < -1000:
            lpath.append(n)
            break
        alpha = np.exp(-n / 10e5)
        gamma = 0.5
        ai = action_idx[a]
        Q[x, y, ai] = (1-alpha)*Q[x, y, ai] + alpha*(r+gamma*Q[x+dpos[0], y+dpos[1]].max())
        n += 1
    try:
        print(f'epoch: {epoch}, n: {n}, alpha: {round(alpha, 6)}')
    except NameError:
        print(f'epoch: {epoch}, n: {n}, alpha: ---')
# Out:
# epoch: 0, n: 1, alpha: 1.0
# epoch: 1, n: 2, alpha: 0.9999990000005
# epoch: 2, n: 3, alpha: 0.999998000002
# epoch: 3, n: 17, alpha: 0.9999840001279993
# epoch: 4, n: 0, alpha: 0.9999840001279993
# epoch: 5, n: 0, alpha: 0.9999840001279993
# epoch: 6, n: 0, alpha: 0.9999840001279993
# epoch: 7, n: 2, alpha: 0.9999990000005
# epoch: 8, n: 0, alpha: 0.9999990000005
# epoch: 9, n: 3, alpha: 0.999998000002
# epoch: 10, n: 2, alpha: 0.9999990000005
# epoch: 11, n: 3, alpha: 0.999998000002
# epoch: 12, n: 0, alpha: 0.999998000002
# epoch: 13, n: 4, alpha: 0.9999970000045
# epoch: 14, n: 5, alpha: 0.999996000008
# epoch: 15, n: 1, alpha: 1.0
# epoch: 16, n: 2, alpha: 0.9999990000005
# epoch: 17, n: 1, alpha: 1.0
# epoch: 18, n: 0, alpha: 1.0
# epoch: 19, n: 3, alpha: 0.999998000002
# epoch: 20, n: 4, alpha: 0.9999970000045
# epoch: 21, n: 4, alpha: 0.9999970000045
# epoch: 22, n: 8, alpha: 0.9999930000245
# epoch: 23, n: 3, alpha: 0.999998000002
# epoch: 24, n: 0, alpha: 0.999998000002
# epoch: 25, n: 0, alpha: 0.999998000002
# epoch: 26, n: 0, alpha: 0.999998000002
# epoch: 27, n: 3, alpha: 0.999998000002
# epoch: 28, n: 1, alpha: 1.0
# epoch: 29, n: 7, alpha: 0.999994000018
# epoch: 30, n: 0, alpha: 0.999994000018
# epoch: 31, n: 0, alpha: 0.999994000018
# epoch: 32, n: 23, alpha: 0.9999780002419982
# epoch: 33, n: 0, alpha: 0.9999780002419982
# epoch: 34, n: 0, alpha: 0.9999780002419982
# epoch: 35, n: 4, alpha: 0.9999970000045
# epoch: 36, n: 0, alpha: 0.9999970000045
# epoch: 37, n: 1, alpha: 1.0
# epoch: 38, n: 0, alpha: 1.0
# epoch: 39, n: 1, alpha: 1.0
# epoch: 40, n: 0, alpha: 1.0
# epoch: 41, n: 1, alpha: 1.0
# epoch: 42, n: 2, alpha: 0.9999990000005
# epoch: 43, n: 1, alpha: 1.0
# epoch: 44, n: 3, alpha: 0.999998000002
# epoch: 45, n: 0, alpha: 0.999998000002
# epoch: 46, n: 1, alpha: 1.0
# epoch: 47, n: 2, alpha: 0.9999990000005
# epoch: 48, n: 0, alpha: 0.9999990000005
# epoch: 49, n: 1, alpha: 1.0
# epoch: 50, n: 3, alpha: 0.999998000002
# epoch: 51, n: 0, alpha: 0.999998000002
# epoch: 52, n: 2, alpha: 0.9999990000005
# epoch: 53, n: 0, alpha: 0.9999990000005
# epoch: 54, n: 0, alpha: 0.9999990000005
# epoch: 55, n: 2, alpha: 0.9999990000005
# epoch: 56, n: 4, alpha: 0.9999970000045
# epoch: 57, n: 4, alpha: 0.9999970000045
# epoch: 58, n: 0, alpha: 0.9999970000045
# epoch: 59, n: 0, alpha: 0.9999970000045
# epoch: 60, n: 0, alpha: 0.9999970000045
# epoch: 61, n: 0, alpha: 0.9999970000045
# epoch: 62, n: 0, alpha: 0.9999970000045
# epoch: 63, n: 1, alpha: 1.0
# epoch: 64, n: 3, alpha: 0.999998000002
# epoch: 65, n: 0, alpha: 0.999998000002
# epoch: 66, n: 0, alpha: 0.999998000002
# epoch: 67, n: 0, alpha: 0.999998000002
# epoch: 68, n: 2, alpha: 0.9999990000005
# epoch: 69, n: 2, alpha: 0.9999990000005
# epoch: 70, n: 2, alpha: 0.9999990000005
# epoch: 71, n: 0, alpha: 0.9999990000005
# epoch: 72, n: 4, alpha: 0.9999970000045
# epoch: 73, n: 1, alpha: 1.0
# epoch: 74, n: 0, alpha: 1.0
# epoch: 75, n: 0, alpha: 1.0
# epoch: 76, n: 1, alpha: 1.0
# epoch: 77, n: 0, alpha: 1.0
# epoch: 78, n: 1, alpha: 1.0
# epoch: 79, n: 0, alpha: 1.0
# epoch: 80, n: 0, alpha: 1.0
# epoch: 81, n: 0, alpha: 1.0
# epoch: 82, n: 1, alpha: 1.0
# epoch: 83, n: 0, alpha: 1.0
# epoch: 84, n: 0, alpha: 1.0
# epoch: 85, n: 1, alpha: 1.0
# epoch: 86, n: 0, alpha: 1.0
# epoch: 87, n: 0, alpha: 1.0
# epoch: 88, n: 0, alpha: 1.0
# epoch: 89, n: 0, alpha: 1.0
# epoch: 90, n: 0, alpha: 1.0
# epoch: 91, n: 1, alpha: 1.0
# epoch: 92, n: 0, alpha: 1.0
# epoch: 93, n: 0, alpha: 1.0
# epoch: 94, n: 0, alpha: 1.0
# epoch: 95, n: 0, alpha: 1.0
# epoch: 96, n: 0, alpha: 1.0
# epoch: 97, n: 0, alpha: 1.0
# epoch: 98, n: 0, alpha: 1.0
# epoch: 99, n: 2, alpha: 0.9999990000005
# epoch: 100, n: 1, alpha: 1.0
# epoch: 101, n: 0, alpha: 1.0
# epoch: 102, n: 1, alpha: 1.0
# epoch: 103, n: 0, alpha: 1.0
# epoch: 104, n: 1, alpha: 1.0
# epoch: 105, n: 0, alpha: 1.0
# epoch: 106, n: 2, alpha: 0.9999990000005
# epoch: 107, n: 1, alpha: 1.0
# epoch: 108, n: 2, alpha: 0.9999990000005
# epoch: 109, n: 0, alpha: 0.9999990000005
# epoch: 110, n: 1, alpha: 1.0
# epoch: 111, n: 0, alpha: 1.0
# epoch: 112, n: 0, alpha: 1.0
# epoch: 113, n: 0, alpha: 1.0
# epoch: 114, n: 1, alpha: 1.0
# epoch: 115, n: 1, alpha: 1.0
# epoch: 116, n: 1, alpha: 1.0
# epoch: 117, n: 0, alpha: 1.0
# epoch: 118, n: 1, alpha: 1.0
# epoch: 119, n: 0, alpha: 1.0
# epoch: 120, n: 0, alpha: 1.0
# epoch: 121, n: 0, alpha: 1.0
# epoch: 122, n: 0, alpha: 1.0
# epoch: 123, n: 1, alpha: 1.0
# epoch: 124, n: 0, alpha: 1.0
# epoch: 125, n: 2, alpha: 0.9999990000005
# epoch: 126, n: 0, alpha: 0.9999990000005
# epoch: 127, n: 0, alpha: 0.9999990000005
# epoch: 128, n: 2, alpha: 0.9999990000005
# epoch: 129, n: 0, alpha: 0.9999990000005
# epoch: 130, n: 0, alpha: 0.9999990000005
# epoch: 131, n: 1, alpha: 1.0
# epoch: 132, n: 0, alpha: 1.0
# epoch: 133, n: 0, alpha: 1.0
# epoch: 134, n: 2, alpha: 0.9999990000005
# epoch: 135, n: 0, alpha: 0.9999990000005
# epoch: 136, n: 0, alpha: 0.9999990000005
# epoch: 137, n: 0, alpha: 0.9999990000005
# epoch: 138, n: 0, alpha: 0.9999990000005
# epoch: 139, n: 1, alpha: 1.0
# epoch: 140, n: 0, alpha: 1.0
# epoch: 141, n: 0, alpha: 1.0
# epoch: 142, n: 1, alpha: 1.0
# epoch: 143, n: 0, alpha: 1.0
# epoch: 144, n: 1, alpha: 1.0
# epoch: 145, n: 1, alpha: 1.0
# epoch: 146, n: 0, alpha: 1.0
# epoch: 147, n: 0, alpha: 1.0
# epoch: 148, n: 1, alpha: 1.0
# epoch: 149, n: 1, alpha: 1.0
# epoch: 150, n: 2, alpha: 0.9999990000005
# epoch: 151, n: 1, alpha: 1.0
# epoch: 152, n: 0, alpha: 1.0
# epoch: 153, n: 0, alpha: 1.0
# epoch: 154, n: 0, alpha: 1.0
# epoch: 155, n: 0, alpha: 1.0
# epoch: 156, n: 0, alpha: 1.0
# epoch: 157, n: 1, alpha: 1.0
# epoch: 158, n: 3, alpha: 0.999998000002
# epoch: 159, n: 1, alpha: 1.0
# epoch: 160, n: 1, alpha: 1.0
# epoch: 161, n: 1, alpha: 1.0
# epoch: 162, n: 0, alpha: 1.0
# epoch: 163, n: 4, alpha: 0.9999970000045
# epoch: 164, n: 0, alpha: 0.9999970000045
# epoch: 165, n: 0, alpha: 0.9999970000045
# epoch: 166, n: 0, alpha: 0.9999970000045
# epoch: 167, n: 0, alpha: 0.9999970000045
# epoch: 168, n: 0, alpha: 0.9999970000045
# epoch: 169, n: 0, alpha: 0.9999970000045
# epoch: 170, n: 1, alpha: 1.0
# epoch: 171, n: 0, alpha: 1.0
# epoch: 172, n: 0, alpha: 1.0
# epoch: 173, n: 0, alpha: 1.0
# epoch: 174, n: 0, alpha: 1.0
# epoch: 175, n: 0, alpha: 1.0
# epoch: 243, n: 2, alpha: 0.9999990000005
# epoch: 244, n: 0, alpha: 0.9999990000005
# epoch: 245, n: 0, alpha: 0.9999990000005
# epoch: 246, n: 0, alpha: 0.9999990000005
# epoch: 247, n: 0, alpha: 0.9999990000005
# epoch: 248, n: 0, alpha: 0.9999990000005
# epoch: 249, n: 0, alpha: 0.9999990000005
# epoch: 250, n: 0, alpha: 0.9999990000005
# epoch: 251, n: 0, alpha: 0.9999990000005
# epoch: 252, n: 0, alpha: 0.9999990000005
# epoch: 253, n: 0, alpha: 0.9999990000005
# epoch: 254, n: 1, alpha: 1.0
# epoch: 255, n: 0, alpha: 1.0
# epoch: 256, n: 0, alpha: 1.0
# epoch: 257, n: 0, alpha: 1.0
# epoch: 258, n: 0, alpha: 1.0
# epoch: 259, n: 0, alpha: 1.0
# epoch: 260, n: 1, alpha: 1.0
# epoch: 261, n: 0, alpha: 1.0
# epoch: 262, n: 0, alpha: 1.0
# epoch: 263, n: 1, alpha: 1.0
# epoch: 264, n: 1, alpha: 1.0
# epoch: 265, n: 0, alpha: 1.0
# epoch: 266, n: 1, alpha: 1.0
# epoch: 267, n: 0, alpha: 1.0
# epoch: 268, n: 0, alpha: 1.0
# epoch: 269, n: 1, alpha: 1.0
# epoch: 270, n: 0, alpha: 1.0
# epoch: 271, n: 0, alpha: 1.0
# epoch: 272, n: 1, alpha: 1.0
# epoch: 273, n: 0, alpha: 1.0
# epoch: 274, n: 1, alpha: 1.0
# epoch: 275, n: 0, alpha: 1.0
# epoch: 276, n: 0, alpha: 1.0
# epoch: 277, n: 2, alpha: 0.9999990000005
# epoch: 278, n: 0, alpha: 0.9999990000005
# epoch: 279, n: 0, alpha: 0.9999990000005
# epoch: 280, n: 0, alpha: 0.9999990000005
# epoch: 281, n: 0, alpha: 0.9999990000005
# epoch: 282, n: 0, alpha: 0.9999990000005
# epoch: 283, n: 0, alpha: 0.9999990000005
# epoch: 284, n: 1, alpha: 1.0
# epoch: 285, n: 0, alpha: 1.0
# epoch: 286, n: 1, alpha: 1.0
# epoch: 287, n: 0, alpha: 1.0
# epoch: 288, n: 0, alpha: 1.0
# epoch: 289, n: 1, alpha: 1.0
# epoch: 290, n: 1, alpha: 1.0
# epoch: 291, n: 0, alpha: 1.0
# epoch: 292, n: 0, alpha: 1.0
# epoch: 293, n: 2, alpha: 0.9999990000005
# epoch: 294, n: 0, alpha: 0.9999990000005
# epoch: 295, n: 0, alpha: 0.9999990000005
# epoch: 296, n: 1, alpha: 1.0
# epoch: 297, n: 0, alpha: 1.0
# epoch: 298, n: 2, alpha: 0.9999990000005
# epoch: 299, n: 0, alpha: 0.9999990000005
# epoch: 300, n: 0, alpha: 0.9999990000005
# epoch: 301, n: 0, alpha: 0.9999990000005
# epoch: 302, n: 0, alpha: 0.9999990000005
# epoch: 303, n: 0, alpha: 0.9999990000005
# epoch: 304, n: 0, alpha: 0.9999990000005
# epoch: 305, n: 1, alpha: 1.0
# epoch: 306, n: 1, alpha: 1.0
# epoch: 307, n: 0, alpha: 1.0
# epoch: 504, n: 1, alpha: 1.0
# epoch: 505, n: 1, alpha: 1.0
# epoch: 506, n: 1, alpha: 1.0
# epoch: 507, n: 2, alpha: 0.9999990000005
# epoch: 508, n: 0, alpha: 0.9999990000005
# epoch: 509, n: 0, alpha: 0.9999990000005
# epoch: 510, n: 1, alpha: 1.0
# epoch: 511, n: 0, alpha: 1.0
# epoch: 512, n: 0, alpha: 1.0
# epoch: 513, n: 1, alpha: 1.0
# epoch: 514, n: 0, alpha: 1.0
# epoch: 515, n: 0, alpha: 1.0
# epoch: 516, n: 0, alpha: 1.0
# epoch: 517, n: 0, alpha: 1.0
# epoch: 518, n: 0, alpha: 1.0
# epoch: 519, n: 0, alpha: 1.0
# epoch: 520, n: 0, alpha: 1.0
# epoch: 521, n: 0, alpha: 1.0
# epoch: 522, n: 0, alpha: 1.0
# epoch: 523, n: 1, alpha: 1.0
# epoch: 524, n: 0, alpha: 1.0
# epoch: 525, n: 1, alpha: 1.0
# epoch: 526, n: 0, alpha: 1.0
# epoch: 527, n: 0, alpha: 1.0
# epoch: 528, n: 0, alpha: 1.0
# epoch: 529, n: 0, alpha: 1.0
# epoch: 530, n: 0, alpha: 1.0
# epoch: 531, n: 0, alpha: 1.0
# epoch: 532, n: 1, alpha: 1.0
# epoch: 533, n: 0, alpha: 1.0
# epoch: 534, n: 1, alpha: 1.0
# epoch: 535, n: 1, alpha: 1.0
# epoch: 536, n: 0, alpha: 1.0
# epoch: 537, n: 2, alpha: 0.9999990000005
# epoch: 538, n: 1, alpha: 1.0
# epoch: 539, n: 0, alpha: 1.0
# epoch: 540, n: 0, alpha: 1.0
# epoch: 541, n: 0, alpha: 1.0
# epoch: 542, n: 0, alpha: 1.0
# epoch: 543, n: 1, alpha: 1.0
# epoch: 544, n: 0, alpha: 1.0
# epoch: 545, n: 0, alpha: 1.0
# epoch: 546, n: 0, alpha: 1.0
# epoch: 547, n: 0, alpha: 1.0
# epoch: 548, n: 0, alpha: 1.0
# epoch: 549, n: 0, alpha: 1.0
# epoch: 550, n: 0, alpha: 1.0
# epoch: 551, n: 0, alpha: 1.0
# epoch: 552, n: 1, alpha: 1.0
# epoch: 553, n: 1, alpha: 1.0
# epoch: 554, n: 0, alpha: 1.0
# epoch: 555, n: 1, alpha: 1.0
# epoch: 556, n: 0, alpha: 1.0
# epoch: 557, n: 0, alpha: 1.0
# epoch: 558, n: 1, alpha: 1.0
# epoch: 559, n: 1, alpha: 1.0
# epoch: 560, n: 1, alpha: 1.0
# epoch: 561, n: 0, alpha: 1.0
# epoch: 562, n: 0, alpha: 1.0
# epoch: 563, n: 2, alpha: 0.9999990000005
# epoch: 564, n: 0, alpha: 0.9999990000005
# epoch: 565, n: 1, alpha: 1.0
# epoch: 566, n: 1, alpha: 1.0
# epoch: 567, n: 0, alpha: 1.0
# epoch: 568, n: 1, alpha: 1.0
# epoch: 569, n: 0, alpha: 1.0
# epoch: 570, n: 2, alpha: 0.9999990000005
# epoch: 571, n: 1, alpha: 1.0
# epoch: 572, n: 0, alpha: 1.0
# epoch: 573, n: 0, alpha: 1.0
# epoch: 574, n: 0, alpha: 1.0
# epoch: 575, n: 1, alpha: 1.0
# epoch: 576, n: 1, alpha: 1.0
# epoch: 577, n: 0, alpha: 1.0
# epoch: 578, n: 1, alpha: 1.0
# epoch: 579, n: 1, alpha: 1.0
# epoch: 580, n: 0, alpha: 1.0
# epoch: 581, n: 0, alpha: 1.0
# epoch: 582, n: 0, alpha: 1.0
# epoch: 583, n: 0, alpha: 1.0
# epoch: 584, n: 0, alpha: 1.0
# epoch: 585, n: 1, alpha: 1.0
# epoch: 586, n: 0, alpha: 1.0
# epoch: 587, n: 0, alpha: 1.0
# epoch: 588, n: 0, alpha: 1.0
# epoch: 589, n: 0, alpha: 1.0
# epoch: 590, n: 0, alpha: 1.0
# epoch: 591, n: 0, alpha: 1.0
# epoch: 592, n: 0, alpha: 1.0
# epoch: 593, n: 1, alpha: 1.0
# epoch: 594, n: 2, alpha: 0.9999990000005
# epoch: 595, n: 2, alpha: 0.9999990000005
# epoch: 596, n: 0, alpha: 0.9999990000005
# epoch: 597, n: 1, alpha: 1.0
# epoch: 598, n: 0, alpha: 1.0
# epoch: 599, n: 0, alpha: 1.0
# epoch: 600, n: 1, alpha: 1.0
# epoch: 601, n: 0, alpha: 1.0
# epoch: 602, n: 0, alpha: 1.0
# epoch: 603, n: 1, alpha: 1.0
# epoch: 604, n: 0, alpha: 1.0
# epoch: 605, n: 1, alpha: 1.0
# epoch: 606, n: 0, alpha: 1.0
# epoch: 607, n: 0, alpha: 1.0
# epoch: 608, n: 0, alpha: 1.0
# epoch: 609, n: 0, alpha: 1.0
# epoch: 610, n: 0, alpha: 1.0
# epoch: 611, n: 0, alpha: 1.0
# epoch: 612, n: 0, alpha: 1.0
# epoch: 613, n: 0, alpha: 1.0
# epoch: 614, n: 0, alpha: 1.0
# epoch: 615, n: 0, alpha: 1.0
# epoch: 616, n: 0, alpha: 1.0
# epoch: 617, n: 0, alpha: 1.0
# epoch: 618, n: 0, alpha: 1.0
# epoch: 619, n: 0, alpha: 1.0
# epoch: 620, n: 0, alpha: 1.0
# epoch: 621, n: 0, alpha: 1.0
# epoch: 622, n: 1, alpha: 1.0
# epoch: 623, n: 2, alpha: 0.9999990000005
# epoch: 624, n: 1, alpha: 1.0
# epoch: 625, n: 0, alpha: 1.0
# epoch: 626, n: 1, alpha: 1.0
# epoch: 627, n: 0, alpha: 1.0
# epoch: 628, n: 0, alpha: 1.0
# epoch: 629, n: 0, alpha: 1.0
# epoch: 630, n: 0, alpha: 1.0
# epoch: 631, n: 0, alpha: 1.0
# epoch: 632, n: 0, alpha: 1.0
# epoch: 633, n: 0, alpha: 1.0
# epoch: 634, n: 0, alpha: 1.0
# epoch: 635, n: 0, alpha: 1.0
# epoch: 636, n: 0, alpha: 1.0
# epoch: 637, n: 1, alpha: 1.0
# epoch: 638, n: 1, alpha: 1.0
# epoch: 639, n: 0, alpha: 1.0
# epoch: 640, n: 0, alpha: 1.0
# epoch: 707, n: 0, alpha: 1.0
# epoch: 708, n: 0, alpha: 1.0
# epoch: 709, n: 1, alpha: 1.0
# epoch: 710, n: 1, alpha: 1.0
# epoch: 711, n: 0, alpha: 1.0
# epoch: 712, n: 0, alpha: 1.0
# epoch: 713, n: 2, alpha: 0.9999990000005
# epoch: 714, n: 0, alpha: 0.9999990000005
# epoch: 715, n: 2, alpha: 0.9999990000005
# epoch: 716, n: 1, alpha: 1.0
# epoch: 717, n: 2, alpha: 0.9999990000005
# epoch: 718, n: 0, alpha: 0.9999990000005
# epoch: 719, n: 0, alpha: 0.9999990000005
# epoch: 720, n: 1, alpha: 1.0
# epoch: 721, n: 0, alpha: 1.0
# epoch: 722, n: 0, alpha: 1.0
# epoch: 723, n: 0, alpha: 1.0
# epoch: 724, n: 0, alpha: 1.0
# epoch: 725, n: 0, alpha: 1.0
# epoch: 726, n: 0, alpha: 1.0
# epoch: 727, n: 0, alpha: 1.0
# epoch: 728, n: 1, alpha: 1.0
# epoch: 729, n: 0, alpha: 1.0
# epoch: 730, n: 1, alpha: 1.0
# epoch: 731, n: 0, alpha: 1.0
# epoch: 732, n: 0, alpha: 1.0
# epoch: 733, n: 0, alpha: 1.0
# epoch: 734, n: 1, alpha: 1.0
# epoch: 735, n: 1, alpha: 1.0
# epoch: 736, n: 0, alpha: 1.0
# epoch: 737, n: 0, alpha: 1.0
# epoch: 738, n: 0, alpha: 1.0
# epoch: 739, n: 0, alpha: 1.0
# epoch: 740, n: 0, alpha: 1.0
# epoch: 741, n: 1, alpha: 1.0
# epoch: 742, n: 2, alpha: 0.9999990000005
# epoch: 743, n: 1, alpha: 1.0
# epoch: 744, n: 0, alpha: 1.0
# epoch: 745, n: 0, alpha: 1.0
# epoch: 746, n: 1, alpha: 1.0
# epoch: 747, n: 0, alpha: 1.0
# epoch: 748, n: 0, alpha: 1.0
# epoch: 749, n: 1, alpha: 1.0
# epoch: 750, n: 1, alpha: 1.0
# epoch: 751, n: 0, alpha: 1.0
# epoch: 752, n: 1, alpha: 1.0
# epoch: 753, n: 1, alpha: 1.0
# epoch: 754, n: 0, alpha: 1.0
# epoch: 755, n: 0, alpha: 1.0
# epoch: 756, n: 0, alpha: 1.0
# epoch: 757, n: 0, alpha: 1.0
# epoch: 758, n: 0, alpha: 1.0
# epoch: 759, n: 1, alpha: 1.0
# epoch: 760, n: 1, alpha: 1.0
# epoch: 761, n: 1, alpha: 1.0
# epoch: 762, n: 0, alpha: 1.0
# epoch: 763, n: 1, alpha: 1.0
# epoch: 764, n: 0, alpha: 1.0
# epoch: 765, n: 0, alpha: 1.0
# epoch: 766, n: 1, alpha: 1.0
# epoch: 767, n: 1, alpha: 1.0
# epoch: 768, n: 0, alpha: 1.0
# epoch: 769, n: 0, alpha: 1.0
# epoch: 770, n: 0, alpha: 1.0
# epoch: 771, n: 0, alpha: 1.0
# epoch: 772, n: 1, alpha: 1.0
# epoch: 773, n: 1, alpha: 1.0
# epoch: 774, n: 0, alpha: 1.0
# epoch: 775, n: 0, alpha: 1.0
# epoch: 776, n: 0, alpha: 1.0
# epoch: 777, n: 0, alpha: 1.0
# epoch: 778, n: 0, alpha: 1.0
# epoch: 779, n: 0, alpha: 1.0
# epoch: 780, n: 1, alpha: 1.0
# epoch: 781, n: 0, alpha: 1.0
# epoch: 782, n: 0, alpha: 1.0
# epoch: 783, n: 0, alpha: 1.0
# epoch: 784, n: 0, alpha: 1.0
# epoch: 785, n: 1, alpha: 1.0
# epoch: 786, n: 0, alpha: 1.0
# epoch: 787, n: 0, alpha: 1.0
# epoch: 788, n: 1, alpha: 1.0
# epoch: 789, n: 0, alpha: 1.0
# epoch: 790, n: 0, alpha: 1.0
# epoch: 791, n: 1, alpha: 1.0
# epoch: 792, n: 0, alpha: 1.0
# epoch: 793, n: 1, alpha: 1.0
# epoch: 794, n: 0, alpha: 1.0
# epoch: 795, n: 1, alpha: 1.0
# epoch: 796, n: 0, alpha: 1.0
# epoch: 797, n: 1, alpha: 1.0
# epoch: 798, n: 0, alpha: 1.0
# epoch: 799, n: 0, alpha: 1.0
# epoch: 800, n: 0, alpha: 1.0
# epoch: 801, n: 0, alpha: 1.0
# epoch: 802, n: 0, alpha: 1.0
# epoch: 803, n: 0, alpha: 1.0
# epoch: 804, n: 1, alpha: 1.0
# epoch: 805, n: 0, alpha: 1.0
# epoch: 806, n: 0, alpha: 1.0
# epoch: 807, n: 0, alpha: 1.0
# epoch: 808, n: 0, alpha: 1.0
# epoch: 809, n: 0, alpha: 1.0
# epoch: 810, n: 0, alpha: 1.0
# epoch: 811, n: 0, alpha: 1.0
# epoch: 812, n: 0, alpha: 1.0
# epoch: 813, n: 3, alpha: 0.999998000002
# epoch: 814, n: 0, alpha: 0.999998000002
# epoch: 815, n: 1, alpha: 1.0
# epoch: 816, n: 0, alpha: 1.0
# epoch: 817, n: 0, alpha: 1.0
# epoch: 818, n: 0, alpha: 1.0
# epoch: 819, n: 0, alpha: 1.0
# epoch: 820, n: 1, alpha: 1.0
# epoch: 821, n: 0, alpha: 1.0
# epoch: 822, n: 0, alpha: 1.0
# epoch: 823, n: 0, alpha: 1.0
# epoch: 824, n: 0, alpha: 1.0
# epoch: 825, n: 1, alpha: 1.0
# epoch: 826, n: 0, alpha: 1.0
# epoch: 827, n: 0, alpha: 1.0
# epoch: 828, n: 1, alpha: 1.0
# epoch: 829, n: 0, alpha: 1.0
# epoch: 830, n: 0, alpha: 1.0
# epoch: 831, n: 1, alpha: 1.0
# epoch: 832, n: 0, alpha: 1.0
# epoch: 833, n: 1, alpha: 1.0
# epoch: 834, n: 1, alpha: 1.0
# epoch: 835, n: 0, alpha: 1.0
# epoch: 836, n: 0, alpha: 1.0
# epoch: 837, n: 0, alpha: 1.0
# epoch: 838, n: 0, alpha: 1.0
# epoch: 839, n: 0, alpha: 1.0
# epoch: 840, n: 1, alpha: 1.0
# epoch: 841, n: 1, alpha: 1.0
# epoch: 842, n: 1, alpha: 1.0
# epoch: 843, n: 1, alpha: 1.0
# epoch: 981, n: 0, alpha: 1.0
# epoch: 982, n: 0, alpha: 1.0
# epoch: 983, n: 0, alpha: 1.0
# epoch: 984, n: 0, alpha: 1.0
# epoch: 985, n: 0, alpha: 1.0
# epoch: 986, n: 0, alpha: 1.0
# epoch: 987, n: 0, alpha: 1.0
# epoch: 988, n: 0, alpha: 1.0
# epoch: 989, n: 1, alpha: 1.0
# epoch: 990, n: 0, alpha: 1.0
# epoch: 991, n: 0, alpha: 1.0
# epoch: 992, n: 1, alpha: 1.0
# epoch: 993, n: 0, alpha: 1.0
# epoch: 994, n: 0, alpha: 1.0
# epoch: 995, n: 0, alpha: 1.0
# epoch: 996, n: 1, alpha: 1.0
# epoch: 997, n: 1, alpha: 1.0
# epoch: 998, n: 1, alpha: 1.0
# epoch: 999, n: 0, alpha: 1.0
# epoch: 1000, n: 0, alpha: 1.0
# epoch: 1001, n: 0, alpha: 1.0
# epoch: 1002, n: 0, alpha: 1.0
# epoch: 1003, n: 0, alpha: 1.0
# epoch: 1004, n: 0, alpha: 1.0
# epoch: 1005, n: 0, alpha: 1.0
# epoch: 1006, n: 0, alpha: 1.0
# epoch: 1007, n: 0, alpha: 1.0
# epoch: 1008, n: 2, alpha: 0.9999990000005
# epoch: 1009, n: 0, alpha: 0.9999990000005
# epoch: 1010, n: 1, alpha: 1.0
# epoch: 1011, n: 0, alpha: 1.0
# epoch: 1012, n: 0, alpha: 1.0
# epoch: 1013, n: 1, alpha: 1.0
# epoch: 1014, n: 0, alpha: 1.0
# epoch: 1015, n: 0, alpha: 1.0
# epoch: 1016, n: 0, alpha: 1.0
# epoch: 1017, n: 1, alpha: 1.0
# epoch: 1018, n: 0, alpha: 1.0
# epoch: 1019, n: 0, alpha: 1.0
# epoch: 1020, n: 0, alpha: 1.0
# epoch: 1021, n: 0, alpha: 1.0
# epoch: 1022, n: 0, alpha: 1.0
# epoch: 1023, n: 0, alpha: 1.0
# epoch: 1024, n: 0, alpha: 1.0
# epoch: 1025, n: 0, alpha: 1.0
# epoch: 1026, n: 0, alpha: 1.0
# epoch: 1027, n: 0, alpha: 1.0
# epoch: 1028, n: 1, alpha: 1.0
# epoch: 1029, n: 1, alpha: 1.0
# epoch: 1030, n: 0, alpha: 1.0
# epoch: 1031, n: 0, alpha: 1.0
# epoch: 1032, n: 1, alpha: 1.0
# epoch: 1033, n: 0, alpha: 1.0
# epoch: 1034, n: 0, alpha: 1.0
# epoch: 1035, n: 1, alpha: 1.0
# epoch: 1036, n: 0, alpha: 1.0
# epoch: 1037, n: 0, alpha: 1.0
# epoch: 1038, n: 0, alpha: 1.0
# epoch: 1039, n: 0, alpha: 1.0
# epoch: 1040, n: 0, alpha: 1.0
# epoch: 1041, n: 0, alpha: 1.0
# epoch: 1042, n: 0, alpha: 1.0
# epoch: 1043, n: 0, alpha: 1.0
# epoch: 1044, n: 0, alpha: 1.0
# epoch: 1045, n: 0, alpha: 1.0
# epoch: 1046, n: 0, alpha: 1.0
# epoch: 1047, n: 0, alpha: 1.0
# epoch: 1048, n: 0, alpha: 1.0
# epoch: 1049, n: 1, alpha: 1.0
# epoch: 1050, n: 0, alpha: 1.0
# epoch: 1051, n: 2, alpha: 0.9999990000005
# epoch: 1052, n: 0, alpha: 0.9999990000005
# epoch: 1053, n: 0, alpha: 0.9999990000005
# epoch: 1054, n: 0, alpha: 0.9999990000005
# epoch: 1055, n: 1, alpha: 1.0
# epoch: 1056, n: 0, alpha: 1.0
# epoch: 1057, n: 1, alpha: 1.0
# epoch: 1058, n: 0, alpha: 1.0
# epoch: 1059, n: 0, alpha: 1.0
# epoch: 1060, n: 0, alpha: 1.0
# epoch: 1061, n: 0, alpha: 1.0
# epoch: 1062, n: 0, alpha: 1.0
# epoch: 1063, n: 1, alpha: 1.0
# epoch: 1064, n: 1, alpha: 1.0
# epoch: 1065, n: 0, alpha: 1.0
# epoch: 1066, n: 0, alpha: 1.0
# epoch: 1067, n: 1, alpha: 1.0
# epoch: 1068, n: 1, alpha: 1.0
# epoch: 1069, n: 2, alpha: 0.9999990000005
# epoch: 1070, n: 1, alpha: 1.0
# epoch: 1071, n: 0, alpha: 1.0
# epoch: 1072, n: 1, alpha: 1.0
# epoch: 1073, n: 0, alpha: 1.0
# epoch: 1074, n: 0, alpha: 1.0
# epoch: 1075, n: 0, alpha: 1.0
# epoch: 1076, n: 1, alpha: 1.0
# epoch: 1077, n: 0, alpha: 1.0
# epoch: 1078, n: 0, alpha: 1.0
# epoch: 1079, n: 0, alpha: 1.0
# epoch: 1080, n: 0, alpha: 1.0
# epoch: 1081, n: 0, alpha: 1.0
# epoch: 1082, n: 1, alpha: 1.0
# epoch: 1083, n: 2, alpha: 0.9999990000005
# epoch: 1084, n: 2, alpha: 0.9999990000005
# epoch: 1085, n: 0, alpha: 0.9999990000005
# epoch: 1086, n: 1, alpha: 1.0
# epoch: 1087, n: 0, alpha: 1.0
# epoch: 1088, n: 1, alpha: 1.0
# epoch: 1089, n: 0, alpha: 1.0
# epoch: 1090, n: 0, alpha: 1.0
# epoch: 1091, n: 0, alpha: 1.0
# epoch: 1092, n: 0, alpha: 1.0
# epoch: 1093, n: 0, alpha: 1.0
# epoch: 1094, n: 0, alpha: 1.0
# epoch: 1095, n: 0, alpha: 1.0
# epoch: 1096, n: 0, alpha: 1.0
# epoch: 1097, n: 1, alpha: 1.0
# epoch: 1098, n: 0, alpha: 1.0
# epoch: 1099, n: 0, alpha: 1.0
# epoch: 1100, n: 1, alpha: 1.0
# epoch: 1101, n: 1, alpha: 1.0
# epoch: 1102, n: 0, alpha: 1.0
# epoch: 1103, n: 0, alpha: 1.0
# epoch: 1104, n: 0, alpha: 1.0
# epoch: 1105, n: 0, alpha: 1.0
# epoch: 1106, n: 0, alpha: 1.0
# epoch: 1107, n: 1, alpha: 1.0
# epoch: 1108, n: 0, alpha: 1.0
# epoch: 1109, n: 1, alpha: 1.0
# epoch: 1110, n: 1, alpha: 1.0
# epoch: 1111, n: 1, alpha: 1.0
# epoch: 1112, n: 1, alpha: 1.0
# epoch: 1113, n: 0, alpha: 1.0
# epoch: 1114, n: 0, alpha: 1.0
# epoch: 1115, n: 0, alpha: 1.0
# epoch: 1116, n: 0, alpha: 1.0
# epoch: 1117, n: 1, alpha: 1.0
# epoch: 1118, n: 1, alpha: 1.0
# epoch: 1119, n: 0, alpha: 1.0
# epoch: 1120, n: 0, alpha: 1.0
# epoch: 1121, n: 0, alpha: 1.0
# epoch: 1122, n: 0, alpha: 1.0
# epoch: 1123, n: 2, alpha: 0.9999990000005
# epoch: 1124, n: 0, alpha: 0.9999990000005
# epoch: 1125, n: 1, alpha: 1.0
# epoch: 1126, n: 1, alpha: 1.0
# epoch: 1127, n: 1, alpha: 1.0
# epoch: 1128, n: 0, alpha: 1.0
# epoch: 1129, n: 0, alpha: 1.0
# epoch: 1130, n: 1, alpha: 1.0
# epoch: 1131, n: 1, alpha: 1.0
# epoch: 1132, n: 0, alpha: 1.0
# epoch: 1133, n: 0, alpha: 1.0
# epoch: 1134, n: 0, alpha: 1.0
# epoch: 1135, n: 1, alpha: 1.0
# epoch: 1136, n: 0, alpha: 1.0
# epoch: 1137, n: 0, alpha: 1.0
# epoch: 1138, n: 0, alpha: 1.0
# epoch: 1139, n: 0, alpha: 1.0
# epoch: 1140, n: 0, alpha: 1.0
# epoch: 1141, n: 1, alpha: 1.0
# epoch: 1142, n: 0, alpha: 1.0
# epoch: 1143, n: 1, alpha: 1.0
# epoch: 1144, n: 0, alpha: 1.0
# epoch: 1145, n: 0, alpha: 1.0
# epoch: 1146, n: 0, alpha: 1.0
# epoch: 1147, n: 0, alpha: 1.0
# epoch: 1148, n: 0, alpha: 1.0
# epoch: 1149, n: 0, alpha: 1.0
# epoch: 1150, n: 3, alpha: 0.999998000002
# epoch: 1151, n: 1, alpha: 1.0
# epoch: 1152, n: 0, alpha: 1.0
# epoch: 1153, n: 0, alpha: 1.0
# epoch: 1154, n: 0, alpha: 1.0
# epoch: 1155, n: 0, alpha: 1.0
# epoch: 1156, n: 0, alpha: 1.0
# epoch: 1157, n: 0, alpha: 1.0
# epoch: 1158, n: 0, alpha: 1.0
# epoch: 1159, n: 1, alpha: 1.0
# epoch: 1160, n: 0, alpha: 1.0
# epoch: 1161, n: 0, alpha: 1.0
# epoch: 1162, n: 0, alpha: 1.0
# epoch: 1163, n: 1, alpha: 1.0
# epoch: 1164, n: 1, alpha: 1.0
# epoch: 1165, n: 0, alpha: 1.0
# epoch: 1166, n: 1, alpha: 1.0
# epoch: 1167, n: 1, alpha: 1.0
# epoch: 1168, n: 0, alpha: 1.0
# epoch: 1169, n: 1, alpha: 1.0
# epoch: 1170, n: 0, alpha: 1.0
# epoch: 1171, n: 1, alpha: 1.0
# epoch: 1172, n: 1, alpha: 1.0
# epoch: 1173, n: 0, alpha: 1.0
# epoch: 1174, n: 0, alpha: 1.0
# epoch: 1175, n: 0, alpha: 1.0
# epoch: 1176, n: 1, alpha: 1.0
# epoch: 1177, n: 0, alpha: 1.0
# epoch: 1178, n: 0, alpha: 1.0
# epoch: 1179, n: 0, alpha: 1.0
# epoch: 1180, n: 0, alpha: 1.0
# epoch: 1181, n: 1, alpha: 1.0
# epoch: 1182, n: 0, alpha: 1.0
# epoch: 1183, n: 0, alpha: 1.0
# epoch: 1184, n: 0, alpha: 1.0
# epoch: 1185, n: 0, alpha: 1.0
# epoch: 1186, n: 0, alpha: 1.0
# epoch: 1187, n: 0, alpha: 1.0
# epoch: 1188, n: 0, alpha: 1.0
# epoch: 1189, n: 0, alpha: 1.0
# epoch: 1190, n: 0, alpha: 1.0
# epoch: 1191, n: 0, alpha: 1.0
# epoch: 1192, n: 1, alpha: 1.0
# epoch: 1193, n: 0, alpha: 1.0
# epoch: 1194, n: 0, alpha: 1.0
# epoch: 1195, n: 0, alpha: 1.0
# epoch: 1196, n: 0, alpha: 1.0
# epoch: 1197, n: 0, alpha: 1.0
# epoch: 1198, n: 1, alpha: 1.0
# epoch: 1199, n: 0, alpha: 1.0
# epoch: 1200, n: 0, alpha: 1.0
# epoch: 1201, n: 0, alpha: 1.0
# epoch: 1202, n: 0, alpha: 1.0
# epoch: 1203, n: 0, alpha: 1.0
# epoch: 1204, n: 0, alpha: 1.0
# epoch: 1205, n: 0, alpha: 1.0
# epoch: 1206, n: 0, alpha: 1.0
# epoch: 1207, n: 0, alpha: 1.0
# epoch: 1208, n: 0, alpha: 1.0
# epoch: 1209, n: 1, alpha: 1.0
# epoch: 1210, n: 0, alpha: 1.0
# epoch: 1211, n: 0, alpha: 1.0
# epoch: 1212, n: 0, alpha: 1.0
# epoch: 1213, n: 1, alpha: 1.0
# epoch: 1214, n: 0, alpha: 1.0
# epoch: 1215, n: 0, alpha: 1.0
# epoch: 1216, n: 0, alpha: 1.0
# epoch: 1217, n: 0, alpha: 1.0
# epoch: 1218, n: 0, alpha: 1.0
# epoch: 1219, n: 0, alpha: 1.0
# epoch: 1220, n: 1, alpha: 1.0
# epoch: 1221, n: 1, alpha: 1.0
# epoch: 1222, n: 1, alpha: 1.0
# epoch: 1223, n: 0, alpha: 1.0
# epoch: 1224, n: 0, alpha: 1.0
# epoch: 1225, n: 0, alpha: 1.0
# epoch: 1226, n: 0, alpha: 1.0
# epoch: 1227, n: 0, alpha: 1.0
# epoch: 1228, n: 0, alpha: 1.0
# epoch: 1229, n: 1, alpha: 1.0
# epoch: 1230, n: 2, alpha: 0.9999990000005
# epoch: 1231, n: 0, alpha: 0.9999990000005
# epoch: 1232, n: 0, alpha: 0.9999990000005
# epoch: 1233, n: 0, alpha: 0.9999990000005
# epoch: 1234, n: 0, alpha: 0.9999990000005
# epoch: 1235, n: 0, alpha: 0.9999990000005
# epoch: 1236, n: 1, alpha: 1.0
# epoch: 1237, n: 0, alpha: 1.0
# epoch: 1238, n: 0, alpha: 1.0
# epoch: 1239, n: 1, alpha: 1.0
# epoch: 1240, n: 0, alpha: 1.0
# epoch: 1241, n: 1, alpha: 1.0
# epoch: 1242, n: 1, alpha: 1.0
# epoch: 1243, n: 1, alpha: 1.0
# epoch: 1244, n: 0, alpha: 1.0
# epoch: 1245, n: 0, alpha: 1.0
# epoch: 1246, n: 0, alpha: 1.0
# epoch: 1247, n: 0, alpha: 1.0
# epoch: 1248, n: 0, alpha: 1.0
# epoch: 1249, n: 0, alpha: 1.0
# epoch: 1250, n: 1, alpha: 1.0
# epoch: 1251, n: 1, alpha: 1.0
# epoch: 1252, n: 0, alpha: 1.0
# epoch: 1253, n: 0, alpha: 1.0
# epoch: 1254, n: 0, alpha: 1.0
# epoch: 1255, n: 0, alpha: 1.0
# epoch: 1256, n: 0, alpha: 1.0
# epoch: 1257, n: 1, alpha: 1.0
# epoch: 1258, n: 1, alpha: 1.0
# epoch: 1259, n: 0, alpha: 1.0
# epoch: 1260, n: 0, alpha: 1.0
# epoch: 1261, n: 0, alpha: 1.0
# epoch: 1262, n: 1, alpha: 1.0
# epoch: 1263, n: 0, alpha: 1.0
# epoch: 1264, n: 1, alpha: 1.0
# epoch: 1265, n: 0, alpha: 1.0
# epoch: 1266, n: 1, alpha: 1.0
# epoch: 1267, n: 0, alpha: 1.0
# epoch: 1268, n: 0, alpha: 1.0
# epoch: 1269, n: 0, alpha: 1.0
# epoch: 1270, n: 1, alpha: 1.0
# epoch: 1271, n: 0, alpha: 1.0
# epoch: 1272, n: 0, alpha: 1.0
# epoch: 1273, n: 0, alpha: 1.0
# epoch: 1274, n: 0, alpha: 1.0
# epoch: 1275, n: 0, alpha: 1.0
# epoch: 1276, n: 0, alpha: 1.0
# epoch: 1277, n: 0, alpha: 1.0
# epoch: 1278, n: 1, alpha: 1.0
# epoch: 1279, n: 0, alpha: 1.0
# epoch: 1280, n: 0, alpha: 1.0
# epoch: 1281, n: 1, alpha: 1.0
# epoch: 1282, n: 1, alpha: 1.0
# epoch: 1283, n: 0, alpha: 1.0
# epoch: 1284, n: 0, alpha: 1.0
# epoch: 1285, n: 0, alpha: 1.0
# epoch: 1286, n: 0, alpha: 1.0
# epoch: 1287, n: 0, alpha: 1.0
# epoch: 1288, n: 0, alpha: 1.0
# epoch: 1289, n: 0, alpha: 1.0
# epoch: 1290, n: 0, alpha: 1.0
# epoch: 1291, n: 0, alpha: 1.0
# epoch: 1292, n: 0, alpha: 1.0
# epoch: 1293, n: 0, alpha: 1.0
# epoch: 1294, n: 0, alpha: 1.0
# epoch: 1295, n: 0, alpha: 1.0
# epoch: 1296, n: 0, alpha: 1.0
# epoch: 1297, n: 0, alpha: 1.0
# epoch: 1298, n: 0, alpha: 1.0
# epoch: 1299, n: 0, alpha: 1.0
# epoch: 1300, n: 2, alpha: 0.9999990000005
# epoch: 1301, n: 0, alpha: 0.9999990000005
# epoch: 1302, n: 1, alpha: 1.0
# epoch: 1303, n: 1, alpha: 1.0
# epoch: 1304, n: 0, alpha: 1.0
# epoch: 1305, n: 0, alpha: 1.0
# epoch: 1306, n: 1, alpha: 1.0
# epoch: 1307, n: 2, alpha: 0.9999990000005
# epoch: 1308, n: 1, alpha: 1.0
# epoch: 1309, n: 0, alpha: 1.0
# epoch: 1310, n: 0, alpha: 1.0
# epoch: 1311, n: 1, alpha: 1.0
# epoch: 1312, n: 0, alpha: 1.0
# epoch: 1313, n: 0, alpha: 1.0
# epoch: 1314, n: 0, alpha: 1.0
# epoch: 1315, n: 1, alpha: 1.0
# epoch: 1316, n: 0, alpha: 1.0
# epoch: 1317, n: 0, alpha: 1.0
# epoch: 1318, n: 0, alpha: 1.0
# epoch: 1319, n: 1, alpha: 1.0
# epoch: 1320, n: 0, alpha: 1.0
# epoch: 1321, n: 0, alpha: 1.0
# epoch: 1322, n: 1, alpha: 1.0
# epoch: 1323, n: 0, alpha: 1.0
# epoch: 1324, n: 0, alpha: 1.0
# epoch: 1325, n: 1, alpha: 1.0
# epoch: 1326, n: 2, alpha: 0.9999990000005
# epoch: 1327, n: 1, alpha: 1.0
# epoch: 1328, n: 0, alpha: 1.0
# epoch: 1329, n: 0, alpha: 1.0
# epoch: 1330, n: 0, alpha: 1.0
# epoch: 1331, n: 0, alpha: 1.0
# epoch: 1332, n: 1, alpha: 1.0
# epoch: 1333, n: 0, alpha: 1.0
# epoch: 1334, n: 0, alpha: 1.0
# epoch: 1335, n: 0, alpha: 1.0
# epoch: 1336, n: 0, alpha: 1.0
# epoch: 1337, n: 2, alpha: 0.9999990000005
# epoch: 1338, n: 0, alpha: 0.9999990000005
# epoch: 1339, n: 0, alpha: 0.9999990000005
# epoch: 1340, n: 1, alpha: 1.0
# epoch: 1341, n: 2, alpha: 0.9999990000005
# epoch: 1342, n: 0, alpha: 0.9999990000005
# epoch: 1343, n: 0, alpha: 0.9999990000005
# epoch: 1344, n: 2, alpha: 0.9999990000005
# epoch: 1345, n: 0, alpha: 0.9999990000005
# epoch: 1346, n: 0, alpha: 0.9999990000005
# epoch: 1347, n: 0, alpha: 0.9999990000005
# epoch: 1348, n: 0, alpha: 0.9999990000005
# epoch: 1349, n: 0, alpha: 0.9999990000005
# epoch: 1350, n: 0, alpha: 0.9999990000005
# epoch: 1351, n: 0, alpha: 0.9999990000005
# epoch: 1352, n: 1, alpha: 1.0
# epoch: 1353, n: 0, alpha: 1.0
# epoch: 1354, n: 1, alpha: 1.0
# epoch: 1355, n: 0, alpha: 1.0
# epoch: 1356, n: 0, alpha: 1.0
# epoch: 1357, n: 0, alpha: 1.0
# epoch: 1358, n: 0, alpha: 1.0
# epoch: 1359, n: 0, alpha: 1.0
# epoch: 1360, n: 2, alpha: 0.9999990000005
# epoch: 1361, n: 0, alpha: 0.9999990000005
# epoch: 1362, n: 0, alpha: 0.9999990000005
# epoch: 1363, n: 0, alpha: 0.9999990000005
# epoch: 1364, n: 1, alpha: 1.0
# epoch: 1365, n: 0, alpha: 1.0
# epoch: 1366, n: 0, alpha: 1.0
# epoch: 1367, n: 1, alpha: 1.0
# epoch: 1368, n: 0, alpha: 1.0
# epoch: 1369, n: 0, alpha: 1.0
# epoch: 1370, n: 1, alpha: 1.0
# epoch: 1371, n: 1, alpha: 1.0
# epoch: 1372, n: 2, alpha: 0.9999990000005
# epoch: 1373, n: 1, alpha: 1.0
# epoch: 1374, n: 0, alpha: 1.0
# epoch: 1375, n: 2, alpha: 0.9999990000005
# epoch: 1376, n: 0, alpha: 0.9999990000005
# epoch: 1377, n: 0, alpha: 0.9999990000005
# epoch: 1378, n: 1, alpha: 1.0
# epoch: 1379, n: 0, alpha: 1.0
# epoch: 1380, n: 0, alpha: 1.0
# epoch: 1381, n: 1, alpha: 1.0
# epoch: 1382, n: 0, alpha: 1.0
# epoch: 1383, n: 1, alpha: 1.0
# epoch: 1384, n: 0, alpha: 1.0
# epoch: 1385, n: 0, alpha: 1.0
# epoch: 1386, n: 1, alpha: 1.0
# epoch: 1387, n: 0, alpha: 1.0
# epoch: 1388, n: 0, alpha: 1.0
# epoch: 1389, n: 0, alpha: 1.0
# epoch: 1390, n: 1, alpha: 1.0
# epoch: 1391, n: 0, alpha: 1.0
# epoch: 1392, n: 1, alpha: 1.0
# epoch: 1393, n: 0, alpha: 1.0
# epoch: 1394, n: 0, alpha: 1.0
# epoch: 1395, n: 0, alpha: 1.0
# epoch: 1396, n: 1, alpha: 1.0
# epoch: 1397, n: 0, alpha: 1.0
# epoch: 1398, n: 2, alpha: 0.9999990000005
# epoch: 1399, n: 1, alpha: 1.0
# epoch: 1400, n: 0, alpha: 1.0
# epoch: 1401, n: 1, alpha: 1.0
# epoch: 1402, n: 0, alpha: 1.0
# epoch: 1403, n: 0, alpha: 1.0
# epoch: 1404, n: 1, alpha: 1.0
# epoch: 1405, n: 0, alpha: 1.0
# epoch: 1406, n: 0, alpha: 1.0
# epoch: 1407, n: 0, alpha: 1.0
# epoch: 1408, n: 0, alpha: 1.0
# epoch: 1409, n: 0, alpha: 1.0
# epoch: 1410, n: 1, alpha: 1.0
# epoch: 1411, n: 0, alpha: 1.0
# epoch: 1412, n: 0, alpha: 1.0
# epoch: 1413, n: 1, alpha: 1.0
# epoch: 1414, n: 0, alpha: 1.0
# epoch: 1415, n: 1, alpha: 1.0
# epoch: 1416, n: 1, alpha: 1.0
# epoch: 1417, n: 0, alpha: 1.0
# epoch: 1418, n: 1, alpha: 1.0
# epoch: 1419, n: 0, alpha: 1.0
# epoch: 1420, n: 0, alpha: 1.0
# epoch: 1421, n: 0, alpha: 1.0
# epoch: 1422, n: 0, alpha: 1.0
# epoch: 1423, n: 0, alpha: 1.0
# epoch: 1424, n: 0, alpha: 1.0
# epoch: 1425, n: 1, alpha: 1.0
# epoch: 1426, n: 0, alpha: 1.0
# epoch: 1427, n: 0, alpha: 1.0
# epoch: 1428, n: 0, alpha: 1.0
# epoch: 1429, n: 0, alpha: 1.0
# epoch: 1430, n: 1, alpha: 1.0
# epoch: 1431, n: 1, alpha: 1.0
# epoch: 1432, n: 0, alpha: 1.0
# epoch: 1433, n: 1, alpha: 1.0
# epoch: 1434, n: 0, alpha: 1.0
# epoch: 1435, n: 1, alpha: 1.0
# epoch: 1436, n: 1, alpha: 1.0
# epoch: 1437, n: 0, alpha: 1.0
# epoch: 1438, n: 0, alpha: 1.0
# epoch: 1439, n: 0, alpha: 1.0
# epoch: 1440, n: 0, alpha: 1.0
# epoch: 1441, n: 0, alpha: 1.0
# epoch: 1442, n: 1, alpha: 1.0
# epoch: 1443, n: 0, alpha: 1.0
# epoch: 1444, n: 1, alpha: 1.0
# epoch: 1445, n: 0, alpha: 1.0
# epoch: 1446, n: 0, alpha: 1.0
# epoch: 1447, n: 0, alpha: 1.0
# epoch: 1448, n: 0, alpha: 1.0
# epoch: 1449, n: 1, alpha: 1.0
# epoch: 1450, n: 0, alpha: 1.0
# epoch: 1451, n: 0, alpha: 1.0
# epoch: 1452, n: 0, alpha: 1.0
# epoch: 1453, n: 0, alpha: 1.0
# epoch: 1454, n: 0, alpha: 1.0
# epoch: 1455, n: 0, alpha: 1.0
# epoch: 1456, n: 1, alpha: 1.0
# epoch: 1457, n: 1, alpha: 1.0
# epoch: 1458, n: 1, alpha: 1.0
# epoch: 1459, n: 0, alpha: 1.0
# epoch: 1460, n: 0, alpha: 1.0
# epoch: 1461, n: 1, alpha: 1.0
# epoch: 1462, n: 0, alpha: 1.0
# epoch: 1463, n: 0, alpha: 1.0
# epoch: 1464, n: 0, alpha: 1.0
# epoch: 1465, n: 1, alpha: 1.0
# epoch: 1466, n: 0, alpha: 1.0
# epoch: 1467, n: 1, alpha: 1.0
# epoch: 1468, n: 0, alpha: 1.0
# epoch: 1469, n: 0, alpha: 1.0
# epoch: 1470, n: 2, alpha: 0.9999990000005
# epoch: 1471, n: 0, alpha: 0.9999990000005
# epoch: 1472, n: 0, alpha: 0.9999990000005
# epoch: 1473, n: 2, alpha: 0.9999990000005
# epoch: 1474, n: 1, alpha: 1.0
# epoch: 1475, n: 1, alpha: 1.0
# epoch: 1476, n: 0, alpha: 1.0
# epoch: 1477, n: 0, alpha: 1.0
# epoch: 1478, n: 0, alpha: 1.0
# epoch: 1479, n: 1, alpha: 1.0
# epoch: 1480, n: 1, alpha: 1.0
# epoch: 1481, n: 0, alpha: 1.0
# epoch: 1482, n: 0, alpha: 1.0
# epoch: 1483, n: 1, alpha: 1.0
# epoch: 1484, n: 0, alpha: 1.0
# epoch: 1485, n: 0, alpha: 1.0
# epoch: 1486, n: 0, alpha: 1.0
# epoch: 1487, n: 1, alpha: 1.0
# epoch: 1488, n: 0, alpha: 1.0
# epoch: 1489, n: 0, alpha: 1.0
# epoch: 1490, n: 1, alpha: 1.0
# epoch: 1491, n: 1, alpha: 1.0
# epoch: 1492, n: 1, alpha: 1.0
# epoch: 1493, n: 0, alpha: 1.0
# epoch: 1494, n: 1, alpha: 1.0
# epoch: 1495, n: 0, alpha: 1.0
# epoch: 1496, n: 0, alpha: 1.0
# epoch: 1497, n: 0, alpha: 1.0
# epoch: 1498, n: 1, alpha: 1.0
# epoch: 1499, n: 0, alpha: 1.0
# epoch: 1500, n: 0, alpha: 1.0
# epoch: 1501, n: 0, alpha: 1.0
# epoch: 1502, n: 0, alpha: 1.0
# epoch: 1503, n: 1, alpha: 1.0
# epoch: 1504, n: 0, alpha: 1.0
# epoch: 1505, n: 1, alpha: 1.0
# epoch: 1506, n: 0, alpha: 1.0
# epoch: 1507, n: 0, alpha: 1.0
# epoch: 1508, n: 0, alpha: 1.0
# epoch: 1509, n: 1, alpha: 1.0
# epoch: 1510, n: 1, alpha: 1.0
# epoch: 1511, n: 0, alpha: 1.0
# epoch: 1512, n: 0, alpha: 1.0
# epoch: 1513, n: 1, alpha: 1.0
# epoch: 1514, n: 0, alpha: 1.0
# epoch: 1515, n: 0, alpha: 1.0
# epoch: 1516, n: 0, alpha: 1.0
# epoch: 1517, n: 1, alpha: 1.0
# epoch: 1518, n: 0, alpha: 1.0
# epoch: 1519, n: 1, alpha: 1.0
# epoch: 1520, n: 0, alpha: 1.0
# epoch: 1521, n: 1, alpha: 1.0
# epoch: 1522, n: 0, alpha: 1.0
# epoch: 1523, n: 0, alpha: 1.0
# ...
# epoch: 40273, n: 0, alpha: 0.999998000002
# epoch: 40274, n: 1, alpha: 1.0
# epoch: 40275, n: 0, alpha: 1.0
# epoch: 40276, n: 0, alpha: 1.0
# epoch: 40277, n: 1, alpha: 1.0
# epoch: 40278, n: 0, alpha: 1.0
# epoch: 40279, n: 0, alpha: 1.0
# epoch: 40280, n: 0, alpha: 1.0
# epoch: 40281, n: 1, alpha: 1.0
# epoch: 40282, n: 0, alpha: 1.0
# epoch: 40283, n: 3, alpha: 0.999998000002
# epoch: 40284, n: 0, alpha: 0.999998000002
# epoch: 40285, n: 0, alpha: 0.999998000002
# epoch: 40286, n: 0, alpha: 0.999998000002
# epoch: 40287, n: 0, alpha: 0.999998000002
# epoch: 40288, n: 0, alpha: 0.999998000002
# epoch: 40289, n: 0, alpha: 0.999998000002
# epoch: 40290, n: 1, alpha: 1.0
# epoch: 40291, n: 2, alpha: 0.9999990000005
# epoch: 40292, n: 1, alpha: 1.0
# epoch: 40293, n: 1, alpha: 1.0
# epoch: 40294, n: 0, alpha: 1.0
# epoch: 40295, n: 0, alpha: 1.0
# epoch: 40296, n: 0, alpha: 1.0
# epoch: 40297, n: 1, alpha: 1.0
# epoch: 40298, n: 0, alpha: 1.0
# epoch: 40299, n: 0, alpha: 1.0
# epoch: 40300, n: 0, alpha: 1.0
# epoch: 40301, n: 0, alpha: 1.0
# epoch: 40302, n: 0, alpha: 1.0
# epoch: 40303, n: 0, alpha: 1.0
# epoch: 40304, n: 0, alpha: 1.0
# epoch: 40305, n: 1, alpha: 1.0
# epoch: 40306, n: 0, alpha: 1.0
# epoch: 40307, n: 1, alpha: 1.0
# epoch: 40308, n: 0, alpha: 1.0
# epoch: 40309, n: 0, alpha: 1.0
# epoch: 40310, n: 1, alpha: 1.0
# epoch: 40311, n: 0, alpha: 1.0
# epoch: 40312, n: 0, alpha: 1.0
# epoch: 40313, n: 0, alpha: 1.0
# epoch: 40314, n: 1, alpha: 1.0
# epoch: 40315, n: 1, alpha: 1.0
# epoch: 40316, n: 1, alpha: 1.0
# epoch: 40317, n: 1, alpha: 1.0
# epoch: 40318, n: 0, alpha: 1.0
# epoch: 40319, n: 3, alpha: 0.999998000002
# epoch: 40320, n: 0, alpha: 0.999998000002
# epoch: 40321, n: 0, alpha: 0.999998000002
# epoch: 40322, n: 0, alpha: 0.999998000002
# epoch: 40323, n: 0, alpha: 0.999998000002
# epoch: 40324, n: 0, alpha: 0.999998000002
# epoch: 40325, n: 0, alpha: 0.999998000002
# epoch: 40326, n: 1, alpha: 1.0
# epoch: 40327, n: 0, alpha: 1.0
# epoch: 40328, n: 0, alpha: 1.0
# epoch: 40329, n: 0, alpha: 1.0
# epoch: 40330, n: 2, alpha: 0.9999990000005
# epoch: 40331, n: 0, alpha: 0.9999990000005
# epoch: 40332, n: 0, alpha: 0.9999990000005
# epoch: 40333, n: 0, alpha: 0.9999990000005
# epoch: 40334, n: 0, alpha: 0.9999990000005
# epoch: 40335, n: 1, alpha: 1.0
# epoch: 40336, n: 0, alpha: 1.0
# epoch: 40337, n: 0, alpha: 1.0
# epoch: 40338, n: 1, alpha: 1.0
# epoch: 40339, n: 0, alpha: 1.0
# epoch: 40340, n: 0, alpha: 1.0
# epoch: 40341, n: 1, alpha: 1.0
# epoch: 40342, n: 0, alpha: 1.0
# epoch: 40343, n: 0, alpha: 1.0
# epoch: 40344, n: 0, alpha: 1.0
# epoch: 40345, n: 0, alpha: 1.0
# epoch: 40346, n: 2, alpha: 0.9999990000005
# epoch: 40347, n: 1, alpha: 1.0
# epoch: 40348, n: 1, alpha: 1.0
# epoch: 40349, n: 0, alpha: 1.0
# epoch: 40350, n: 0, alpha: 1.0
# epoch: 40351, n: 0, alpha: 1.0
# epoch: 40352, n: 0, alpha: 1.0
# epoch: 40353, n: 1, alpha: 1.0
# epoch: 40354, n: 0, alpha: 1.0
# epoch: 40355, n: 0, alpha: 1.0
# epoch: 40356, n: 0, alpha: 1.0
# epoch: 40357, n: 0, alpha: 1.0
# epoch: 40358, n: 0, alpha: 1.0
# epoch: 40359, n: 1, alpha: 1.0
# epoch: 40360, n: 0, alpha: 1.0
# epoch: 40361, n: 0, alpha: 1.0
# epoch: 40362, n: 0, alpha: 1.0
# epoch: 40363, n: 0, alpha: 1.0
# epoch: 40364, n: 0, alpha: 1.0
# epoch: 40365, n: 0, alpha: 1.0
# epoch: 40366, n: 1, alpha: 1.0
# epoch: 40367, n: 0, alpha: 1.0
# epoch: 40368, n: 1, alpha: 1.0
# epoch: 40369, n: 0, alpha: 1.0
# epoch: 40370, n: 0, alpha: 1.0
# epoch: 40371, n: 0, alpha: 1.0
# epoch: 40372, n: 0, alpha: 1.0
# epoch: 40373, n: 1, alpha: 1.0
# epoch: 40374, n: 0, alpha: 1.0
# epoch: 40375, n: 0, alpha: 1.0
# epoch: 40376, n: 0, alpha: 1.0
# epoch: 40377, n: 0, alpha: 1.0
# epoch: 40378, n: 0, alpha: 1.0
# epoch: 40379, n: 0, alpha: 1.0
# epoch: 40380, n: 0, alpha: 1.0
# epoch: 40381, n: 0, alpha: 1.0
# epoch: 40382, n: 0, alpha: 1.0
# epoch: 40383, n: 1, alpha: 1.0
# epoch: 40384, n: 0, alpha: 1.0
# epoch: 40385, n: 1, alpha: 1.0
# epoch: 40386, n: 0, alpha: 1.0
# epoch: 40387, n: 1, alpha: 1.0
# epoch: 40388, n: 1, alpha: 1.0
# epoch: 40389, n: 1, alpha: 1.0
# epoch: 40390, n: 1, alpha: 1.0
# epoch: 40391, n: 0, alpha: 1.0
# epoch: 40392, n: 1, alpha: 1.0
# epoch: 40393, n: 0, alpha: 1.0
# epoch: 40394, n: 1, alpha: 1.0
# epoch: 40395, n: 1, alpha: 1.0
# epoch: 40396, n: 0, alpha: 1.0
# epoch: 40397, n: 0, alpha: 1.0
# epoch: 40398, n: 1, alpha: 1.0
# epoch: 40399, n: 0, alpha: 1.0
# epoch: 40400, n: 3, alpha: 0.999998000002
# epoch: 40401, n: 1, alpha: 1.0
# epoch: 40402, n: 1, alpha: 1.0
# epoch: 40403, n: 0, alpha: 1.0
# epoch: 40404, n: 0, alpha: 1.0
# epoch: 40405, n: 1, alpha: 1.0
# epoch: 40406, n: 1, alpha: 1.0
# epoch: 40407, n: 1, alpha: 1.0
# epoch: 40408, n: 1, alpha: 1.0
# epoch: 40409, n: 0, alpha: 1.0
# epoch: 40410, n: 0, alpha: 1.0
# epoch: 40411, n: 0, alpha: 1.0
# epoch: 40412, n: 1, alpha: 1.0
# epoch: 40413, n: 0, alpha: 1.0
# epoch: 40414, n: 0, alpha: 1.0
# epoch: 40415, n: 1, alpha: 1.0
# epoch: 40416, n: 1, alpha: 1.0
# epoch: 40417, n: 3, alpha: 0.999998000002
# epoch: 40418, n: 3, alpha: 0.999998000002
# epoch: 40419, n: 2, alpha: 0.9999990000005
# epoch: 40420, n: 2, alpha: 0.9999990000005
# epoch: 40421, n: 1, alpha: 1.0
# epoch: 40422, n: 0, alpha: 1.0
# epoch: 40423, n: 0, alpha: 1.0
# epoch: 40424, n: 0, alpha: 1.0
# epoch: 40425, n: 2, alpha: 0.9999990000005
# epoch: 40426, n: 0, alpha: 0.9999990000005
# epoch: 40427, n: 0, alpha: 0.9999990000005
# epoch: 40428, n: 0, alpha: 0.9999990000005
# epoch: 40429, n: 0, alpha: 0.9999990000005
# epoch: 40430, n: 0, alpha: 0.9999990000005
# epoch: 40431, n: 0, alpha: 0.9999990000005
# epoch: 40432, n: 0, alpha: 0.9999990000005
# epoch: 40433, n: 0, alpha: 0.9999990000005
# epoch: 40434, n: 1, alpha: 1.0
# epoch: 40435, n: 0, alpha: 1.0
# epoch: 40436, n: 1, alpha: 1.0
# epoch: 40437, n: 0, alpha: 1.0
# epoch: 40438, n: 0, alpha: 1.0
# epoch: 40439, n: 0, alpha: 1.0
# epoch: 40440, n: 0, alpha: 1.0
# epoch: 40441, n: 0, alpha: 1.0
# epoch: 40442, n: 0, alpha: 1.0
# epoch: 40443, n: 0, alpha: 1.0
# epoch: 40444, n: 1, alpha: 1.0
# epoch: 40445, n: 0, alpha: 1.0
# epoch: 40446, n: 0, alpha: 1.0
# epoch: 40447, n: 0, alpha: 1.0
# epoch: 40448, n: 0, alpha: 1.0
# epoch: 40449, n: 0, alpha: 1.0
# epoch: 40450, n: 1, alpha: 1.0
# epoch: 40451, n: 0, alpha: 1.0
# epoch: 40452, n: 0, alpha: 1.0
# epoch: 40453, n: 1, alpha: 1.0
# epoch: 40454, n: 0, alpha: 1.0
# epoch: 40455, n: 1, alpha: 1.0
# epoch: 40456, n: 0, alpha: 1.0
# epoch: 40457, n: 0, alpha: 1.0
# epoch: 40458, n: 0, alpha: 1.0
# epoch: 40459, n: 0, alpha: 1.0
# epoch: 40460, n: 0, alpha: 1.0
# epoch: 40461, n: 0, alpha: 1.0
# epoch: 40462, n: 1, alpha: 1.0
# epoch: 40463, n: 0, alpha: 1.0
# epoch: 40464, n: 1, alpha: 1.0
# epoch: 40465, n: 0, alpha: 1.0
# epoch: 40466, n: 2, alpha: 0.9999990000005
# epoch: 40467, n: 0, alpha: 0.9999990000005
# epoch: 40468, n: 0, alpha: 0.9999990000005
# epoch: 40469, n: 1, alpha: 1.0
# epoch: 40470, n: 0, alpha: 1.0
# epoch: 40471, n: 1, alpha: 1.0
# epoch: 40472, n: 0, alpha: 1.0
# epoch: 40473, n: 0, alpha: 1.0
# epoch: 40474, n: 0, alpha: 1.0
# epoch: 40475, n: 0, alpha: 1.0
# epoch: 40476, n: 0, alpha: 1.0
# epoch: 40477, n: 1, alpha: 1.0
# epoch: 40478, n: 0, alpha: 1.0
# epoch: 40479, n: 0, alpha: 1.0
# epoch: 40480, n: 1, alpha: 1.0
# epoch: 40481, n: 0, alpha: 1.0
# epoch: 40482, n: 0, alpha: 1.0
# epoch: 40483, n: 0, alpha: 1.0
# epoch: 40484, n: 2, alpha: 0.9999990000005
# epoch: 40485, n: 0, alpha: 0.9999990000005
# epoch: 40486, n: 1, alpha: 1.0
# epoch: 40487, n: 0, alpha: 1.0
# epoch: 40488, n: 0, alpha: 1.0
# epoch: 40489, n: 0, alpha: 1.0
# epoch: 40490, n: 1, alpha: 1.0
# epoch: 40491, n: 1, alpha: 1.0
# epoch: 40492, n: 0, alpha: 1.0
# epoch: 40493, n: 1, alpha: 1.0
# epoch: 40494, n: 0, alpha: 1.0
# epoch: 40495, n: 0, alpha: 1.0
# epoch: 40496, n: 0, alpha: 1.0
# epoch: 40497, n: 0, alpha: 1.0
# epoch: 40498, n: 0, alpha: 1.0
# epoch: 40499, n: 1, alpha: 1.0
# epoch: 40500, n: 0, alpha: 1.0
# epoch: 40501, n: 0, alpha: 1.0
# epoch: 40502, n: 0, alpha: 1.0
# epoch: 40503, n: 2, alpha: 0.9999990000005
# epoch: 40504, n: 0, alpha: 0.9999990000005
# epoch: 40505, n: 1, alpha: 1.0
# epoch: 40506, n: 0, alpha: 1.0
# epoch: 40507, n: 0, alpha: 1.0
# epoch: 40508, n: 0, alpha: 1.0
# epoch: 40509, n: 1, alpha: 1.0
# epoch: 40510, n: 0, alpha: 1.0
# epoch: 40511, n: 1, alpha: 1.0
# epoch: 40512, n: 0, alpha: 1.0
# epoch: 40513, n: 0, alpha: 1.0
# epoch: 40514, n: 0, alpha: 1.0
# epoch: 40515, n: 2, alpha: 0.9999990000005
# epoch: 40516, n: 0, alpha: 0.9999990000005
# epoch: 40517, n: 0, alpha: 0.9999990000005
# epoch: 40518, n: 0, alpha: 0.9999990000005
# epoch: 40519, n: 0, alpha: 0.9999990000005
# epoch: 40520, n: 0, alpha: 0.9999990000005
# epoch: 40521, n: 1, alpha: 1.0
# epoch: 40522, n: 0, alpha: 1.0
# epoch: 40523, n: 0, alpha: 1.0
# epoch: 40524, n: 0, alpha: 1.0
# epoch: 40525, n: 1, alpha: 1.0
# epoch: 40526, n: 0, alpha: 1.0
# epoch: 40527, n: 0, alpha: 1.0
# epoch: 40528, n: 1, alpha: 1.0
# epoch: 40529, n: 0, alpha: 1.0
# epoch: 40530, n: 0, alpha: 1.0
# epoch: 40531, n: 0, alpha: 1.0
# epoch: 40532, n: 1, alpha: 1.0
# epoch: 40533, n: 0, alpha: 1.0
# epoch: 40534, n: 0, alpha: 1.0
# epoch: 40535, n: 1, alpha: 1.0
# epoch: 40536, n: 2, alpha: 0.9999990000005
# epoch: 40537, n: 0, alpha: 0.9999990000005
# epoch: 40538, n: 0, alpha: 0.9999990000005
# epoch: 40539, n: 0, alpha: 0.9999990000005
# epoch: 40540, n: 0, alpha: 0.9999990000005
# epoch: 40541, n: 1, alpha: 1.0
# epoch: 40542, n: 0, alpha: 1.0
# epoch: 40543, n: 2, alpha: 0.9999990000005
# epoch: 40544, n: 0, alpha: 0.9999990000005
# epoch: 40545, n: 1, alpha: 1.0
# epoch: 40546, n: 0, alpha: 1.0
# epoch: 40547, n: 0, alpha: 1.0
# epoch: 40548, n: 1, alpha: 1.0
# epoch: 40549, n: 1, alpha: 1.0
# epoch: 40550, n: 0, alpha: 1.0
# epoch: 40551, n: 0, alpha: 1.0
# epoch: 40552, n: 0, alpha: 1.0
# epoch: 40553, n: 1, alpha: 1.0
# epoch: 40554, n: 0, alpha: 1.0
# epoch: 40555, n: 1, alpha: 1.0
# epoch: 40556, n: 0, alpha: 1.0
# epoch: 40557, n: 0, alpha: 1.0
# epoch: 40558, n: 0, alpha: 1.0
# epoch: 40559, n: 0, alpha: 1.0
# epoch: 40560, n: 0, alpha: 1.0
# epoch: 40561, n: 0, alpha: 1.0
# epoch: 40562, n: 0, alpha: 1.0
# epoch: 40563, n: 1, alpha: 1.0
# epoch: 40564, n: 0, alpha: 1.0
# epoch: 40565, n: 1, alpha: 1.0
# epoch: 40566, n: 0, alpha: 1.0
# epoch: 40567, n: 1, alpha: 1.0
# epoch: 40568, n: 1, alpha: 1.0
# epoch: 40569, n: 2, alpha: 0.9999990000005
# epoch: 40570, n: 1, alpha: 1.0
# epoch: 40571, n: 2, alpha: 0.9999990000005
# epoch: 40572, n: 0, alpha: 0.9999990000005
# epoch: 40573, n: 1, alpha: 1.0
# epoch: 40574, n: 1, alpha: 1.0
# epoch: 40575, n: 0, alpha: 1.0
# epoch: 40576, n: 0, alpha: 1.0
# epoch: 40577, n: 0, alpha: 1.0
# epoch: 40578, n: 0, alpha: 1.0
# epoch: 40579, n: 1, alpha: 1.0
# epoch: 40580, n: 0, alpha: 1.0
# epoch: 40581, n: 0, alpha: 1.0
# epoch: 40582, n: 0, alpha: 1.0
# epoch: 40583, n: 0, alpha: 1.0
# epoch: 40584, n: 0, alpha: 1.0
# epoch: 40585, n: 0, alpha: 1.0
# epoch: 40586, n: 0, alpha: 1.0
# epoch: 40587, n: 0, alpha: 1.0
# epoch: 40588, n: 0, alpha: 1.0
# epoch: 40589, n: 0, alpha: 1.0
# epoch: 40590, n: 0, alpha: 1.0
# epoch: 40591, n: 0, alpha: 1.0
# epoch: 40592, n: 0, alpha: 1.0
# epoch: 40593, n: 0, alpha: 1.0
# epoch: 40594, n: 0, alpha: 1.0
# epoch: 40595, n: 2, alpha: 0.9999990000005
# epoch: 40596, n: 1, alpha: 1.0
# epoch: 40597, n: 1, alpha: 1.0
# epoch: 40598, n: 0, alpha: 1.0
# epoch: 40599, n: 0, alpha: 1.0
# epoch: 40600, n: 0, alpha: 1.0
# epoch: 40601, n: 0, alpha: 1.0
# epoch: 40602, n: 1, alpha: 1.0
# epoch: 40603, n: 0, alpha: 1.0
# epoch: 40604, n: 1, alpha: 1.0
# epoch: 40605, n: 0, alpha: 1.0
# epoch: 40606, n: 2, alpha: 0.9999990000005
# epoch: 40607, n: 0, alpha: 0.9999990000005
# epoch: 40608, n: 0, alpha: 0.9999990000005
# epoch: 40609, n: 1, alpha: 1.0
# epoch: 40610, n: 0, alpha: 1.0
# epoch: 40611, n: 0, alpha: 1.0
# epoch: 40612, n: 0, alpha: 1.0
# epoch: 40613, n: 0, alpha: 1.0
# epoch: 40614, n: 0, alpha: 1.0
# epoch: 40615, n: 0, alpha: 1.0
# epoch: 40616, n: 0, alpha: 1.0
# epoch: 40617, n: 0, alpha: 1.0
# epoch: 40618, n: 5, alpha: 0.999996000008
# epoch: 40619, n: 1, alpha: 1.0
# epoch: 40620, n: 1, alpha: 1.0
# epoch: 40621, n: 0, alpha: 1.0
# epoch: 40622, n: 1, alpha: 1.0
# epoch: 40623, n: 1, alpha: 1.0
# epoch: 40624, n: 0, alpha: 1.0
# epoch: 40625, n: 1, alpha: 1.0
# epoch: 40626, n: 1, alpha: 1.0
# epoch: 40627, n: 0, alpha: 1.0
# epoch: 40628, n: 1, alpha: 1.0
# epoch: 40629, n: 1, alpha: 1.0
# epoch: 40630, n: 0, alpha: 1.0
# epoch: 40631, n: 1, alpha: 1.0
# epoch: 40632, n: 0, alpha: 1.0
# epoch: 40633, n: 0, alpha: 1.0
# epoch: 40634, n: 1, alpha: 1.0
# epoch: 40635, n: 0, alpha: 1.0
# epoch: 40636, n: 0, alpha: 1.0
# epoch: 40637, n: 0, alpha: 1.0
# epoch: 40638, n: 1, alpha: 1.0
# epoch: 40639, n: 0, alpha: 1.0
# epoch: 40640, n: 0, alpha: 1.0
# epoch: 40641, n: 1, alpha: 1.0
# epoch: 40642, n: 1, alpha: 1.0
# epoch: 40643, n: 0, alpha: 1.0
# epoch: 40644, n: 1, alpha: 1.0
# epoch: 40645, n: 1, alpha: 1.0
# epoch: 40646, n: 0, alpha: 1.0
# epoch: 40647, n: 0, alpha: 1.0
# epoch: 40648, n: 0, alpha: 1.0
# epoch: 40649, n: 0, alpha: 1.0
# epoch: 40650, n: 0, alpha: 1.0
# epoch: 40651, n: 1, alpha: 1.0
# epoch: 40652, n: 1, alpha: 1.0
# epoch: 40653, n: 4, alpha: 0.9999970000045
# epoch: 40654, n: 1, alpha: 1.0
# epoch: 40655, n: 2, alpha: 0.9999990000005
# epoch: 40656, n: 0, alpha: 0.9999990000005
# epoch: 40657, n: 0, alpha: 0.9999990000005
# epoch: 40658, n: 0, alpha: 0.9999990000005
# epoch: 40659, n: 1, alpha: 1.0
# epoch: 40660, n: 1, alpha: 1.0
# epoch: 40661, n: 1, alpha: 1.0
# epoch: 40662, n: 0, alpha: 1.0
# epoch: 40663, n: 0, alpha: 1.0
# epoch: 40664, n: 1, alpha: 1.0
# epoch: 40665, n: 0, alpha: 1.0
# epoch: 40666, n: 0, alpha: 1.0
# epoch: 40667, n: 1, alpha: 1.0
# epoch: 40668, n: 1, alpha: 1.0
# epoch: 40669, n: 0, alpha: 1.0
# epoch: 40670, n: 0, alpha: 1.0
# epoch: 40671, n: 0, alpha: 1.0
# epoch: 40672, n: 1, alpha: 1.0
# epoch: 40673, n: 0, alpha: 1.0
# epoch: 40674, n: 0, alpha: 1.0
# epoch: 40675, n: 0, alpha: 1.0
# epoch: 40676, n: 0, alpha: 1.0
# epoch: 40677, n: 1, alpha: 1.0
# epoch: 40678, n: 0, alpha: 1.0
# epoch: 40679, n: 0, alpha: 1.0
# epoch: 40680, n: 3, alpha: 0.999998000002
# epoch: 40681, n: 0, alpha: 0.999998000002
# epoch: 40682, n: 0, alpha: 0.999998000002
# epoch: 40683, n: 0, alpha: 0.999998000002
# epoch: 40684, n: 0, alpha: 0.999998000002
# epoch: 40685, n: 1, alpha: 1.0
# epoch: 40686, n: 0, alpha: 1.0
# epoch: 40687, n: 1, alpha: 1.0
# epoch: 40688, n: 1, alpha: 1.0
# epoch: 40689, n: 0, alpha: 1.0
# epoch: 40690, n: 0, alpha: 1.0
# epoch: 40691, n: 0, alpha: 1.0
# epoch: 40692, n: 0, alpha: 1.0
# epoch: 40693, n: 1, alpha: 1.0
# epoch: 40694, n: 2, alpha: 0.9999990000005
# epoch: 40695, n: 0, alpha: 0.9999990000005
# epoch: 40696, n: 0, alpha: 0.9999990000005
# epoch: 40697, n: 1, alpha: 1.0
# epoch: 40698, n: 0, alpha: 1.0
# epoch: 40699, n: 1, alpha: 1.0
# epoch: 40700, n: 0, alpha: 1.0
# epoch: 40701, n: 0, alpha: 1.0
# epoch: 40702, n: 0, alpha: 1.0
# epoch: 40703, n: 1, alpha: 1.0
# epoch: 40704, n: 0, alpha: 1.0
# epoch: 40705, n: 1, alpha: 1.0
# epoch: 40706, n: 0, alpha: 1.0
# epoch: 40707, n: 0, alpha: 1.0
# epoch: 40708, n: 0, alpha: 1.0
# epoch: 40709, n: 0, alpha: 1.0
# epoch: 40710, n: 0, alpha: 1.0
# epoch: 40711, n: 0, alpha: 1.0
# epoch: 40712, n: 0, alpha: 1.0
# epoch: 40713, n: 0, alpha: 1.0
# epoch: 40714, n: 0, alpha: 1.0
# epoch: 40715, n: 0, alpha: 1.0
# epoch: 40716, n: 0, alpha: 1.0
# epoch: 40717, n: 0, alpha: 1.0
# epoch: 40718, n: 0, alpha: 1.0
# epoch: 40719, n: 1, alpha: 1.0
# epoch: 40720, n: 1, alpha: 1.0
# epoch: 40721, n: 0, alpha: 1.0
# epoch: 40722, n: 1, alpha: 1.0
# epoch: 40723, n: 2, alpha: 0.9999990000005
# epoch: 40724, n: 1, alpha: 1.0
# epoch: 40725, n: 0, alpha: 1.0
# epoch: 40726, n: 2, alpha: 0.9999990000005
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11034/2405070981.py in <module>
#      13     while True:
#      14         x, y = m.human
# ---> 15         v = probs(Q[x, y])
#      16         a = random.choices(list(actions), weights=v)[0]
#      17         dpos = actions[a]
#
# /tmp/ipykernel_11034/3896633951.py in probs(v, eps)
#       1 # code block 7
#       2 def probs(v, eps=1e-4):
# ----> 3     v = v - v.min() + eps
#       4     v = v / v.sum()
#       5     return v
#
# ~/.local/lib/python3.9/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      41 def _amin(a, axis=None, out=None, keepdims=False,
#      42           initial=_NoValue, where=True):
# ---> 43     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      44
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %% [markdown]
# After executing this algorithm, the Q-Table should be updated with values that define the attractiveness of different actions at each step. Visualize the table here:

# %%
m.plot(Q)

# %% [markdown]
# ## Checking the Policy
#
# Since Q-Table lists the "attractiveness" of each action at each state, it is quite easy to use it to define the efficient navigation in our world. In the simplest case, we can just select the action corresponding to the highest Q-Table value:

# %%
# code block 9
def qpolicy_strict(m):
    x, y = m.human
    v = probs(Q[x, y])
    a = list(actions)[np.argmax(v)]
    return a

walk(m, qpolicy_strict)
# Out:
# 4

# %% [markdown]
# If you try the code above several times, you may notice that sometimes it just "hangs", and you need to press the STOP button in the notebook to interrupt it.
#
# > **Task 1:** Modify the `walk` function to limit the maximum length of path by a certain number of steps (say, 100), and watch the code above return this value from time to time.
#
# > **Task 2:** Modify the `walk` function so that it does not go back to the places where is has already been previously. This will prevent `walk` from looping, however, the agent can still end up being "trapped" in a location from which it is unable to escape.

# %%
# code block 10
def qpolicy(m):
    x, y = m.human
    v = probs(Q[x,y])
    a = random.choices(list(actions),weights=v)[0]
    return a

print_statistics(qpolicy)
# Out:
# Average path length = 2.19672131147541, eaten by wolf: 39 times

# %% [markdown]
# ## Investigating the Learning Process

# %%
plt.plot(lpath)

# %% [markdown]
# ## Exercise
# ## A more realistic Peter and the Wolf world
